# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4813609973572109218
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10875765224
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 12923105368434697868
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %% [markdown]
# **Importing the necessary packages**

# %%
# Tensorflow essentials
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import *

# specifically for cnn
from tensorflow.keras.layers import Dropout, Flatten,Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization,MaxPool2D,GlobalAveragePooling2D
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16

import numpy as np 
import pandas as pd
import os
from sklearn.metrics import *
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import cv2
from glob import glob
from pathlib import Path
import random

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# **Reading the image files**

# %%
dire= 'F:\\Ml files\\jute disease\\data\\jute leaf disease dataset'
categories=['Healthy', 'Powdery mildew', 'Yellow mosaic']

# %%
features=[]
for i in tqdm(categories):
    path=os.path.join(dire,i)
    num_classes=categories.index(i)
    for img in os.listdir(path):
        if img.endswith('.png'): 
            img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_COLOR)
            img_array=cv2.resize(img_array,(150,150))
            features.append([img_array,num_classes])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:18<00:00,  6.04s/it]

# %%
X=[]
y=[]
for i,j in features:
    X.append(i)
    y.append(j)

# %% [markdown]
# **Example of flower images per class**

# %%
# Set global variables
TRAIN_DIR = 'F:\\Ml files\\jute disease\\data\\jute leaf disease dataset'
CLASSES = [folder[len(TRAIN_DIR) + 1:] for folder in glob(TRAIN_DIR + '/*')]
CLASSES.sort()

TARGET_SIZE = (64, 64)
TARGET_DIMS = (64, 64, 3) # add channel for RGB
N_CLASSES = 42
VALIDATION_SPLIT = 0.1
BATCH_SIZE = 64

def plot_one_sample_of_each(base_path):
    cols = 4
    rows = int(np.ceil(len(CLASSES) / cols))
    fig = plt.figure(figsize=(16, 20))
    
    for i in range(len(CLASSES)):
        cls = CLASSES[i]
        img_path = base_path + '/' + cls + '/**'
        path_contents = glob(img_path)
    
        imgs = random.sample(path_contents, 1)

        sp = plt.subplot(rows, cols, i + 1)
        plt.imshow(cv2.imread(imgs[0]))
        
        plt.title(cls)
        sp.axis('off')

    plt.show()
    return

plot_one_sample_of_each(TRAIN_DIR)

# %%
X=np.array(X).reshape(-1,150,150,3)/255.0

# %% [markdown]
# **Class destribution**

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(20,7))
fig=sns.countplot(y)
fig.set(xticks=range(len(categories)), xticklabels=[i for i in categories])
plt.xticks(rotation=40)
plt.xlabel('Jute Leaf Categories')
plt.show()

# %%
list_healthy=len([i for i in y if i==0])
list_powdery_mildew=len([i for i in y if i==1])
list_yellow_mosaic=len([i for i in y if i==2])
list_species=[list_healthy,list_powdery_mildew,list_yellow_mosaic]

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(18,10))
plt.pie(list_species,labels=categories,startangle=90,colors=['#e6194b', '#3cb44b', '#ffe119'],
        autopct='%1.1f%%',explode = (0,0,0),shadow=True,textprops={'fontsize': 20})

# plt.title('Percentage of images per class', fontsize = 40)
plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Times New Roman']
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),prop={'size': 20},
          fancybox=True, shadow=True, ncol=3)
plt.show()

# %%
from tensorflow.keras.utils import to_categorical
y=to_categorical(y)

# %% [markdown]
# **Train Test split**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=12)

# %%
print("Shape of x_train", x_train.shape)
print("Shape of y_train", y_train.shape)
print("Shape of x_test", x_test.shape)
print("Shape of y_test", y_test.shape)
# Out:
# Shape of x_train (1444, 150, 150, 3)
# Shape of y_train (1444, 3)
# Shape of x_test (361, 150, 150, 3)
# Shape of y_test (361, 3)

# %% [markdown]
# **CNN Model**

# %%
def cnn_model(input_shape):
  model = Sequential()
  model.add(Conv2D(32, (3, 3), input_shape=(input_shape)))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(2, 2, padding="same"))
  model.add(Dropout(0.2))
  
  model.add(Conv2D(64, (3, 3)))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(2, 2, padding="same"))
  model.add(Dropout(0.2))
  
  model.add(Conv2D(128, (3, 3)))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(2, 2, padding="same"))
  model.add(Dropout(0.2))
  
  model.add(Flatten())
  
  model.add(Dense(512, activation="relu"))
  
  model.add(Dropout(0.2))
  model.add(Dense(128, activation="relu"))
  model.add(Dropout(0.2))
  model.add(Dense(3, activation="softmax"))

  model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
  
  return model

# %% [markdown]
# **Augmentation to avoid overfitting**

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images
datagen.fit(x_train)

# %% [markdown]
# **Callbacks**

# %%
keras.backend.clear_session()
#callback function for early stopping

accuracy_threshold = 0.99999

class myCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
      if(logs.get('accuracy')>99.99):
        print("\nReached %2.2f%% accuracy so we will stop trianing" % (accuracy_threshold*100))
        self.model.stop_training = True

acc_callback = myCallback()

checkpoint_path = 'F:\\Ml files\\jute disease\\model\\kfold-cnn-class_11.h5'
epochs=50

callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', patience=15, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint(monitor='val_loss', mode='min', filepath=checkpoint_path, verbose=1, save_best_only=True, save_weights_only=False),
    acc_callback
]

# %%
#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=50, BATCH_SIZE=128):
    model = None
    input_shape = 150,150,3
    model = cnn_model(input_shape)
    results = model.fit_generator(datagen.flow(t_x, t_y, batch_size=BATCH_SIZE),
                              epochs = EPOCHS, validation_data = (val_x,val_y),
                              callbacks= callbacks,
                              verbose = 1, steps_per_epoch= t_x.shape[0] // 128)
    
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs = 100
batch_size = 128

model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# C:\Users\Ovi\anaconda3\envs\tensrgpu\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 10/10 [==============================] - 6s 609ms/step - loss: 1.9925 - accuracy: 0.3415 - val_loss: 1.0952 - val_accuracy: 0.4138
#
# Epoch 00001: val_loss improved from inf to 1.09521, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 2/100
# 10/10 [==============================] - 3s 290ms/step - loss: 1.0755 - accuracy: 0.3827 - val_loss: 0.9733 - val_accuracy: 0.2897
#
# Epoch 00002: val_loss improved from 1.09521 to 0.97326, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 3/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.8846 - accuracy: 0.5506 - val_loss: 1.0496 - val_accuracy: 0.4552
#
# Epoch 00003: val_loss did not improve from 0.97326
# Epoch 4/100
# 10/10 [==============================] - 3s 288ms/step - loss: 0.6774 - accuracy: 0.6822 - val_loss: 0.7347 - val_accuracy: 0.7241
#
# Epoch 00004: val_loss improved from 0.97326 to 0.73469, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 5/100
# 10/10 [==============================] - 3s 291ms/step - loss: 0.5695 - accuracy: 0.7507 - val_loss: 0.9055 - val_accuracy: 0.6138
#
# Epoch 00005: val_loss did not improve from 0.73469
# Epoch 6/100
# 10/10 [==============================] - 3s 297ms/step - loss: 0.5144 - accuracy: 0.8028 - val_loss: 0.6214 - val_accuracy: 0.7862
#
# Epoch 00006: val_loss improved from 0.73469 to 0.62135, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 7/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.4582 - accuracy: 0.8244 - val_loss: 0.4557 - val_accuracy: 0.8483
#
# Epoch 00007: val_loss improved from 0.62135 to 0.45569, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 8/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.4230 - accuracy: 0.8409 - val_loss: 0.5040 - val_accuracy: 0.8069
#
# Epoch 00008: val_loss did not improve from 0.45569
# Epoch 9/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.4060 - accuracy: 0.8472 - val_loss: 0.6523 - val_accuracy: 0.7724
#
# Epoch 00009: val_loss did not improve from 0.45569
# Epoch 10/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.4319 - accuracy: 0.8406 - val_loss: 0.4718 - val_accuracy: 0.8069
#
# Epoch 00010: val_loss did not improve from 0.45569
# Epoch 11/100
# 10/10 [==============================] - 3s 288ms/step - loss: 0.3640 - accuracy: 0.8710 - val_loss: 0.3610 - val_accuracy: 0.8552
#
# Epoch 00011: val_loss improved from 0.45569 to 0.36099, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 12/100
# 10/10 [==============================] - 3s 278ms/step - loss: 0.3944 - accuracy: 0.8348 - val_loss: 0.4647 - val_accuracy: 0.8207
#
# Epoch 00012: val_loss did not improve from 0.36099
# Epoch 13/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.4156 - accuracy: 0.8521 - val_loss: 0.3848 - val_accuracy: 0.8276
#
# Epoch 00013: val_loss did not improve from 0.36099
# Epoch 14/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.3131 - accuracy: 0.8972 - val_loss: 0.5551 - val_accuracy: 0.7931
#
# Epoch 00014: val_loss did not improve from 0.36099
# Epoch 15/100
# 10/10 [==============================] - 3s 271ms/step - loss: 0.3726 - accuracy: 0.8573 - val_loss: 0.3586 - val_accuracy: 0.8483
#
# Epoch 00015: val_loss improved from 0.36099 to 0.35865, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 16/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.3340 - accuracy: 0.8704 - val_loss: 0.6109 - val_accuracy: 0.7862
#
# Epoch 00016: val_loss did not improve from 0.35865
# Epoch 17/100
# 10/10 [==============================] - 3s 266ms/step - loss: 0.3100 - accuracy: 0.8878 - val_loss: 0.2383 - val_accuracy: 0.9172
#
# Epoch 00017: val_loss improved from 0.35865 to 0.23827, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 18/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.3587 - accuracy: 0.8917 - val_loss: 0.2264 - val_accuracy: 0.9034
#
# Epoch 00018: val_loss improved from 0.23827 to 0.22643, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 19/100
# 10/10 [==============================] - 3s 292ms/step - loss: 0.3199 - accuracy: 0.8854 - val_loss: 0.2392 - val_accuracy: 0.8897
#
# Epoch 00019: val_loss did not improve from 0.22643
# Epoch 20/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.2701 - accuracy: 0.8875 - val_loss: 0.2726 - val_accuracy: 0.9103
#
# Epoch 00020: val_loss did not improve from 0.22643
# Epoch 21/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.3201 - accuracy: 0.8761 - val_loss: 0.2257 - val_accuracy: 0.9172
#
# Epoch 00021: val_loss improved from 0.22643 to 0.22572, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 22/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.2682 - accuracy: 0.9008 - val_loss: 0.3367 - val_accuracy: 0.8621
#
# Epoch 00022: val_loss did not improve from 0.22572
# Epoch 23/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.3685 - accuracy: 0.8695 - val_loss: 0.3543 - val_accuracy: 0.9034
#
# Epoch 00023: val_loss did not improve from 0.22572
# Epoch 24/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.2727 - accuracy: 0.8919 - val_loss: 0.1535 - val_accuracy: 0.9517
#
# Epoch 00024: val_loss improved from 0.22572 to 0.15347, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 25/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.2721 - accuracy: 0.8933 - val_loss: 0.1776 - val_accuracy: 0.9310
#
# Epoch 00025: val_loss did not improve from 0.15347
# Epoch 26/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.2770 - accuracy: 0.9063 - val_loss: 0.2222 - val_accuracy: 0.9379
#
# Epoch 00026: val_loss did not improve from 0.15347
# Epoch 27/100
# 10/10 [==============================] - 3s 265ms/step - loss: 0.1808 - accuracy: 0.9351 - val_loss: 0.8022 - val_accuracy: 0.8483
#
# Epoch 00027: val_loss did not improve from 0.15347
# Epoch 28/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.2520 - accuracy: 0.9150 - val_loss: 0.1701 - val_accuracy: 0.9517
#
# Epoch 00028: val_loss did not improve from 0.15347
# Epoch 29/100
# 10/10 [==============================] - 3s 268ms/step - loss: 0.2807 - accuracy: 0.9072 - val_loss: 0.1129 - val_accuracy: 0.9586
#
# Epoch 00029: val_loss improved from 0.15347 to 0.11286, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 30/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.1968 - accuracy: 0.9222 - val_loss: 0.3114 - val_accuracy: 0.9310
#
# Epoch 00030: val_loss did not improve from 0.11286
# Epoch 31/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.2017 - accuracy: 0.9358 - val_loss: 0.8464 - val_accuracy: 0.8138
#
# Epoch 00031: val_loss did not improve from 0.11286
# Epoch 32/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.2015 - accuracy: 0.9345 - val_loss: 0.9391 - val_accuracy: 0.8414
#
# Epoch 00032: val_loss did not improve from 0.11286
# Epoch 33/100
# 10/10 [==============================] - 3s 278ms/step - loss: 0.1715 - accuracy: 0.9345 - val_loss: 0.3808 - val_accuracy: 0.9172
#
# Epoch 00033: val_loss did not improve from 0.11286
# Epoch 34/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.1716 - accuracy: 0.9465 - val_loss: 0.2305 - val_accuracy: 0.9517
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00034: val_loss did not improve from 0.11286
# Epoch 35/100
# 10/10 [==============================] - 3s 267ms/step - loss: 0.1374 - accuracy: 0.9520 - val_loss: 0.3478 - val_accuracy: 0.9448
#
# Epoch 00035: val_loss did not improve from 0.11286
# Epoch 36/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.1130 - accuracy: 0.9636 - val_loss: 0.6996 - val_accuracy: 0.8897
#
# Epoch 00036: val_loss did not improve from 0.11286
# Epoch 37/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.1149 - accuracy: 0.9632 - val_loss: 0.5657 - val_accuracy: 0.9103
#
# Epoch 00037: val_loss did not improve from 0.11286
# Epoch 38/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.1333 - accuracy: 0.9506 - val_loss: 0.2618 - val_accuracy: 0.9586
#
# Epoch 00038: val_loss did not improve from 0.11286
# Epoch 39/100
# 10/10 [==============================] - 3s 287ms/step - loss: 0.1291 - accuracy: 0.9586 - val_loss: 0.3977 - val_accuracy: 0.9241
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00039: val_loss did not improve from 0.11286
# Epoch 40/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.1033 - accuracy: 0.9613 - val_loss: 0.4128 - val_accuracy: 0.9241
#
# Epoch 00040: val_loss did not improve from 0.11286
# Epoch 41/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.0948 - accuracy: 0.9683 - val_loss: 0.4608 - val_accuracy: 0.9241
#
# Epoch 00041: val_loss did not improve from 0.11286
# Epoch 42/100
# 10/10 [==============================] - 3s 313ms/step - loss: 0.1589 - accuracy: 0.9463 - val_loss: 0.4986 - val_accuracy: 0.9103
#
# Epoch 00042: val_loss did not improve from 0.11286
# Epoch 43/100
# 10/10 [==============================] - 3s 294ms/step - loss: 0.1054 - accuracy: 0.9669 - val_loss: 0.5099 - val_accuracy: 0.9103
#
# Epoch 00043: val_loss did not improve from 0.11286
# Epoch 44/100
# 10/10 [==============================] - 3s 314ms/step - loss: 0.1094 - accuracy: 0.9601 - val_loss: 0.5427 - val_accuracy: 0.9103
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00044: val_loss did not improve from 0.11286
# Epoch 00044: early stopping
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5427 - accuracy: 0.9103
# Val Score:  [0.5427247881889343, 0.9103448390960693]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 10/10 [==============================] - 3s 300ms/step - loss: 2.5219 - accuracy: 0.3129 - val_loss: 1.0677 - val_accuracy: 0.2966
#
# Epoch 00001: val_loss did not improve from 0.11286
# Epoch 2/100
# 10/10 [==============================] - 3s 286ms/step - loss: 1.0122 - accuracy: 0.4209 - val_loss: 0.9120 - val_accuracy: 0.3655
#
# Epoch 00002: val_loss did not improve from 0.11286
# Epoch 3/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.7630 - accuracy: 0.6037 - val_loss: 0.5516 - val_accuracy: 0.7793
#
# Epoch 00003: val_loss did not improve from 0.11286
# Epoch 4/100
# 10/10 [==============================] - 3s 287ms/step - loss: 0.6887 - accuracy: 0.6838 - val_loss: 0.5858 - val_accuracy: 0.7172
#
# Epoch 00004: val_loss did not improve from 0.11286
# Epoch 5/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.5924 - accuracy: 0.7579 - val_loss: 0.4686 - val_accuracy: 0.8276
#
# Epoch 00005: val_loss did not improve from 0.11286
# Epoch 6/100
# 10/10 [==============================] - 3s 293ms/step - loss: 0.5218 - accuracy: 0.8059 - val_loss: 0.4588 - val_accuracy: 0.8276
#
# Epoch 00006: val_loss did not improve from 0.11286
# Epoch 7/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.5022 - accuracy: 0.8027 - val_loss: 0.3773 - val_accuracy: 0.8690
#
# Epoch 00007: val_loss did not improve from 0.11286
# Epoch 8/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.5010 - accuracy: 0.8102 - val_loss: 0.4067 - val_accuracy: 0.8690
#
# Epoch 00008: val_loss did not improve from 0.11286
# Epoch 9/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.5466 - accuracy: 0.7993 - val_loss: 0.6389 - val_accuracy: 0.7517
#
# Epoch 00009: val_loss did not improve from 0.11286
# Epoch 10/100
# 10/10 [==============================] - 3s 268ms/step - loss: 0.5153 - accuracy: 0.8092 - val_loss: 0.4666 - val_accuracy: 0.8000
#
# Epoch 00010: val_loss did not improve from 0.11286
# Epoch 11/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.4322 - accuracy: 0.8411 - val_loss: 0.4258 - val_accuracy: 0.8552
#
# Epoch 00011: val_loss did not improve from 0.11286
# Epoch 12/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.4522 - accuracy: 0.8327 - val_loss: 0.3749 - val_accuracy: 0.8897
#
# Epoch 00012: val_loss did not improve from 0.11286
# Epoch 13/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.4192 - accuracy: 0.8237 - val_loss: 0.3390 - val_accuracy: 0.8828
#
# Epoch 00013: val_loss did not improve from 0.11286
# Epoch 14/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.4183 - accuracy: 0.8388 - val_loss: 0.3544 - val_accuracy: 0.8897
#
# Epoch 00014: val_loss did not improve from 0.11286
# Epoch 15/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.4283 - accuracy: 0.8419 - val_loss: 0.3186 - val_accuracy: 0.9034
#
# Epoch 00015: val_loss did not improve from 0.11286
# Epoch 16/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.3985 - accuracy: 0.8529 - val_loss: 0.4048 - val_accuracy: 0.8276
#
# Epoch 00016: val_loss did not improve from 0.11286
# Epoch 17/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.4090 - accuracy: 0.8432 - val_loss: 0.3140 - val_accuracy: 0.8621
#
# Epoch 00017: val_loss did not improve from 0.11286
# Epoch 18/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.3440 - accuracy: 0.8708 - val_loss: 0.3139 - val_accuracy: 0.8759
#
# Epoch 00018: val_loss did not improve from 0.11286
# Epoch 19/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.3563 - accuracy: 0.8773 - val_loss: 0.3113 - val_accuracy: 0.8828
#
# Epoch 00019: val_loss did not improve from 0.11286
# Epoch 20/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.3871 - accuracy: 0.8558 - val_loss: 0.2347 - val_accuracy: 0.8966
#
# Epoch 00020: val_loss did not improve from 0.11286
# Epoch 21/100
# 10/10 [==============================] - 3s 296ms/step - loss: 0.3525 - accuracy: 0.8622 - val_loss: 0.2281 - val_accuracy: 0.9103
#
# Epoch 00021: val_loss did not improve from 0.11286
# Epoch 22/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.3507 - accuracy: 0.8784 - val_loss: 0.2317 - val_accuracy: 0.9172
#
# Epoch 00022: val_loss did not improve from 0.11286
# Epoch 23/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.3191 - accuracy: 0.8766 - val_loss: 0.1975 - val_accuracy: 0.9379
#
# Epoch 00023: val_loss did not improve from 0.11286
# Epoch 24/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.3446 - accuracy: 0.8683 - val_loss: 0.3574 - val_accuracy: 0.8483
#
# Epoch 00024: val_loss did not improve from 0.11286
# Epoch 25/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.3139 - accuracy: 0.8754 - val_loss: 0.2010 - val_accuracy: 0.9241
#
# Epoch 00025: val_loss did not improve from 0.11286
# Epoch 26/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.2815 - accuracy: 0.9044 - val_loss: 0.1898 - val_accuracy: 0.9241
#
# Epoch 00026: val_loss did not improve from 0.11286
# Epoch 27/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.2929 - accuracy: 0.8909 - val_loss: 0.1983 - val_accuracy: 0.9379
#
# Epoch 00027: val_loss did not improve from 0.11286
# Epoch 28/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.2761 - accuracy: 0.8901 - val_loss: 0.1971 - val_accuracy: 0.9448
#
# Epoch 00028: val_loss did not improve from 0.11286
# Epoch 29/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.2945 - accuracy: 0.8903 - val_loss: 0.2287 - val_accuracy: 0.9103
#
# Epoch 00029: val_loss did not improve from 0.11286
# Epoch 30/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.2705 - accuracy: 0.9007 - val_loss: 0.2031 - val_accuracy: 0.9310
#
# Epoch 00030: val_loss did not improve from 0.11286
# Epoch 31/100
# 10/10 [==============================] - 3s 287ms/step - loss: 0.3060 - accuracy: 0.8863 - val_loss: 0.1985 - val_accuracy: 0.9241
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00031: val_loss did not improve from 0.11286
# Epoch 32/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.2382 - accuracy: 0.9154 - val_loss: 0.1875 - val_accuracy: 0.9310
#
# Epoch 00032: val_loss did not improve from 0.11286
# Epoch 33/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.2251 - accuracy: 0.9130 - val_loss: 0.1872 - val_accuracy: 0.9379
#
# Epoch 00033: val_loss did not improve from 0.11286
# Epoch 34/100
# 10/10 [==============================] - 3s 269ms/step - loss: 0.1968 - accuracy: 0.9276 - val_loss: 0.1942 - val_accuracy: 0.9379
#
# Epoch 00034: val_loss did not improve from 0.11286
# Epoch 35/100
# 10/10 [==============================] - 3s 291ms/step - loss: 0.2488 - accuracy: 0.9061 - val_loss: 0.1855 - val_accuracy: 0.9379
#
# Epoch 00035: val_loss did not improve from 0.11286
# Epoch 36/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.1906 - accuracy: 0.9339 - val_loss: 0.1813 - val_accuracy: 0.9379
#
# Epoch 00036: val_loss did not improve from 0.11286
# Epoch 37/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.1930 - accuracy: 0.9325 - val_loss: 0.1825 - val_accuracy: 0.9448
#
# Epoch 00037: val_loss did not improve from 0.11286
# Epoch 38/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.2024 - accuracy: 0.9211 - val_loss: 0.1863 - val_accuracy: 0.9379
#
# Epoch 00038: val_loss did not improve from 0.11286
# Epoch 39/100
# 10/10 [==============================] - 3s 267ms/step - loss: 0.2063 - accuracy: 0.9093 - val_loss: 0.1899 - val_accuracy: 0.9448
#
# Epoch 00039: val_loss did not improve from 0.11286
# Epoch 40/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.1724 - accuracy: 0.9355 - val_loss: 0.1847 - val_accuracy: 0.9448
#
# Epoch 00040: val_loss did not improve from 0.11286
# Epoch 41/100
# 10/10 [==============================] - 3s 266ms/step - loss: 0.1701 - accuracy: 0.9276 - val_loss: 0.1862 - val_accuracy: 0.9448
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00041: val_loss did not improve from 0.11286
# Epoch 42/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.1681 - accuracy: 0.9349 - val_loss: 0.1853 - val_accuracy: 0.9448
#
# Epoch 00042: val_loss did not improve from 0.11286
# Epoch 43/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.1956 - accuracy: 0.9248 - val_loss: 0.1844 - val_accuracy: 0.9448
#
# Epoch 00043: val_loss did not improve from 0.11286
# Epoch 44/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.1733 - accuracy: 0.9278 - val_loss: 0.1845 - val_accuracy: 0.9448
#
# Epoch 00044: val_loss did not improve from 0.11286
# Epoch 45/100
# 10/10 [==============================] - 3s 287ms/step - loss: 0.1763 - accuracy: 0.9324 - val_loss: 0.1857 - val_accuracy: 0.9448
#
# Epoch 00045: val_loss did not improve from 0.11286
# Epoch 46/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.1829 - accuracy: 0.9332 - val_loss: 0.1853 - val_accuracy: 0.9517
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00046: val_loss did not improve from 0.11286
# Epoch 47/100
# 10/10 [==============================] - 3s 310ms/step - loss: 0.1479 - accuracy: 0.9428 - val_loss: 0.1853 - val_accuracy: 0.9517
#
# Epoch 00047: val_loss did not improve from 0.11286
# Epoch 48/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.1729 - accuracy: 0.9380 - val_loss: 0.1854 - val_accuracy: 0.9517
#
# Epoch 00048: val_loss did not improve from 0.11286
# Epoch 49/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.2161 - accuracy: 0.9113 - val_loss: 0.1854 - val_accuracy: 0.9517
#
# Epoch 00049: val_loss did not improve from 0.11286
# Epoch 50/100
# 10/10 [==============================] - 3s 307ms/step - loss: 0.1979 - accuracy: 0.9196 - val_loss: 0.1854 - val_accuracy: 0.9517
#
# Epoch 00050: val_loss did not improve from 0.11286
# Epoch 51/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.1877 - accuracy: 0.9283 - val_loss: 0.1854 - val_accuracy: 0.9517
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00051: val_loss did not improve from 0.11286
# Epoch 00051: early stopping
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1854 - accuracy: 0.9517
# Val Score:  [0.18544183671474457, 0.951724112033844]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 10/10 [==============================] - 3s 298ms/step - loss: 2.3407 - accuracy: 0.3027 - val_loss: 1.0738 - val_accuracy: 0.4000
#
# Epoch 00001: val_loss did not improve from 0.11286
# Epoch 2/100
# 10/10 [==============================] - 3s 282ms/step - loss: 1.0595 - accuracy: 0.3275 - val_loss: 0.7816 - val_accuracy: 0.6138
#
# Epoch 00002: val_loss did not improve from 0.11286
# Epoch 3/100
# 10/10 [==============================] - 3s 269ms/step - loss: 0.7778 - accuracy: 0.5769 - val_loss: 0.6097 - val_accuracy: 0.7448
#
# Epoch 00003: val_loss did not improve from 0.11286
# Epoch 4/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.6705 - accuracy: 0.7044 - val_loss: 0.4722 - val_accuracy: 0.8414
#
# Epoch 00004: val_loss did not improve from 0.11286
# Epoch 5/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.5421 - accuracy: 0.7896 - val_loss: 0.4852 - val_accuracy: 0.8483
#
# Epoch 00005: val_loss did not improve from 0.11286
# Epoch 6/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.5264 - accuracy: 0.8170 - val_loss: 0.4191 - val_accuracy: 0.8759
#
# Epoch 00006: val_loss did not improve from 0.11286
# Epoch 7/100
# 10/10 [==============================] - 3s 311ms/step - loss: 0.4703 - accuracy: 0.8360 - val_loss: 0.3967 - val_accuracy: 0.8828
#
# Epoch 00007: val_loss did not improve from 0.11286
# Epoch 8/100
# 10/10 [==============================] - 3s 308ms/step - loss: 0.4560 - accuracy: 0.8350 - val_loss: 0.3729 - val_accuracy: 0.8828
#
# Epoch 00008: val_loss did not improve from 0.11286
# Epoch 9/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.4393 - accuracy: 0.8344 - val_loss: 0.4987 - val_accuracy: 0.7862
#
# Epoch 00009: val_loss did not improve from 0.11286
# Epoch 10/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.4473 - accuracy: 0.8277 - val_loss: 0.3608 - val_accuracy: 0.8897
#
# Epoch 00010: val_loss did not improve from 0.11286
# Epoch 11/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.4152 - accuracy: 0.8342 - val_loss: 0.3207 - val_accuracy: 0.9034
#
# Epoch 00011: val_loss did not improve from 0.11286
# Epoch 12/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.3634 - accuracy: 0.8629 - val_loss: 0.2947 - val_accuracy: 0.9034
#
# Epoch 00012: val_loss did not improve from 0.11286
# Epoch 13/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.3431 - accuracy: 0.8780 - val_loss: 0.2761 - val_accuracy: 0.9103
#
# Epoch 00013: val_loss did not improve from 0.11286
# Epoch 14/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.3702 - accuracy: 0.8587 - val_loss: 0.3704 - val_accuracy: 0.8552
#
# Epoch 00014: val_loss did not improve from 0.11286
# Epoch 15/100
# 10/10 [==============================] - 3s 287ms/step - loss: 0.3685 - accuracy: 0.8685 - val_loss: 0.2431 - val_accuracy: 0.9172
#
# Epoch 00015: val_loss did not improve from 0.11286
# Epoch 16/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.3588 - accuracy: 0.8632 - val_loss: 0.2608 - val_accuracy: 0.9034
#
# Epoch 00016: val_loss did not improve from 0.11286
# Epoch 17/100
# 10/10 [==============================] - 3s 296ms/step - loss: 0.3655 - accuracy: 0.8711 - val_loss: 0.3053 - val_accuracy: 0.8690
#
# Epoch 00017: val_loss did not improve from 0.11286
# Epoch 18/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.3033 - accuracy: 0.8881 - val_loss: 0.2143 - val_accuracy: 0.9241
#
# Epoch 00018: val_loss did not improve from 0.11286
# Epoch 19/100
# 10/10 [==============================] - 3s 317ms/step - loss: 0.2841 - accuracy: 0.8928 - val_loss: 0.2209 - val_accuracy: 0.9172
#
# Epoch 00019: val_loss did not improve from 0.11286
# Epoch 20/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.2841 - accuracy: 0.8850 - val_loss: 0.1659 - val_accuracy: 0.9034
#
# Epoch 00020: val_loss did not improve from 0.11286
# Epoch 21/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.2849 - accuracy: 0.8899 - val_loss: 0.1276 - val_accuracy: 0.9586
#
# Epoch 00021: val_loss did not improve from 0.11286
# Epoch 22/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.2740 - accuracy: 0.8875 - val_loss: 1.1595 - val_accuracy: 0.7931
#
# Epoch 00022: val_loss did not improve from 0.11286
# Epoch 23/100
# 10/10 [==============================] - 3s 289ms/step - loss: 0.6164 - accuracy: 0.8028 - val_loss: 0.2248 - val_accuracy: 0.8966
#
# Epoch 00023: val_loss did not improve from 0.11286
# Epoch 24/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.3179 - accuracy: 0.8824 - val_loss: 0.1435 - val_accuracy: 0.9448
#
# Epoch 00024: val_loss did not improve from 0.11286
# Epoch 25/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.2490 - accuracy: 0.9071 - val_loss: 0.1191 - val_accuracy: 0.9448
#
# Epoch 00025: val_loss did not improve from 0.11286
# Epoch 26/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.2250 - accuracy: 0.9145 - val_loss: 0.1521 - val_accuracy: 0.9310
#
# Epoch 00026: val_loss did not improve from 0.11286
# Epoch 27/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.2203 - accuracy: 0.9172 - val_loss: 0.1094 - val_accuracy: 0.9586
#
# Epoch 00027: val_loss improved from 0.11286 to 0.10944, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 28/100
# 10/10 [==============================] - 3s 266ms/step - loss: 0.3071 - accuracy: 0.8883 - val_loss: 0.1229 - val_accuracy: 0.9379
#
# Epoch 00028: val_loss did not improve from 0.10944
# Epoch 29/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.2075 - accuracy: 0.9203 - val_loss: 0.1276 - val_accuracy: 0.9379
#
# Epoch 00029: val_loss did not improve from 0.10944
# Epoch 30/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.1981 - accuracy: 0.9406 - val_loss: 0.1261 - val_accuracy: 0.9448
#
# Epoch 00030: val_loss did not improve from 0.10944
# Epoch 31/100
# 10/10 [==============================] - 3s 287ms/step - loss: 0.1769 - accuracy: 0.9355 - val_loss: 0.1055 - val_accuracy: 0.9655
#
# Epoch 00031: val_loss improved from 0.10944 to 0.10549, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 32/100
# 10/10 [==============================] - 3s 269ms/step - loss: 0.1836 - accuracy: 0.9389 - val_loss: 0.1085 - val_accuracy: 0.9517
#
# Epoch 00032: val_loss did not improve from 0.10549
# Epoch 33/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.1711 - accuracy: 0.9450 - val_loss: 0.0739 - val_accuracy: 0.9793
#
# Epoch 00033: val_loss improved from 0.10549 to 0.07394, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 34/100
# 10/10 [==============================] - 3s 278ms/step - loss: 0.1427 - accuracy: 0.9464 - val_loss: 0.0992 - val_accuracy: 0.9586
#
# Epoch 00034: val_loss did not improve from 0.07394
# Epoch 35/100
# 10/10 [==============================] - 3s 310ms/step - loss: 0.1331 - accuracy: 0.9536 - val_loss: 0.0295 - val_accuracy: 1.0000
#
# Epoch 00035: val_loss improved from 0.07394 to 0.02953, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 36/100
# 10/10 [==============================] - 3s 295ms/step - loss: 0.1490 - accuracy: 0.9514 - val_loss: 0.1100 - val_accuracy: 0.9586
#
# Epoch 00036: val_loss did not improve from 0.02953
# Epoch 37/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.1256 - accuracy: 0.9596 - val_loss: 0.1236 - val_accuracy: 0.9448
#
# Epoch 00037: val_loss did not improve from 0.02953
# Epoch 38/100
# 10/10 [==============================] - 3s 268ms/step - loss: 0.0585 - accuracy: 0.9810 - val_loss: 0.1469 - val_accuracy: 0.9448
#
# Epoch 00038: val_loss did not improve from 0.02953
# Epoch 39/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.0568 - accuracy: 0.9791 - val_loss: 0.0170 - val_accuracy: 1.0000
#
# Epoch 00039: val_loss improved from 0.02953 to 0.01703, saving model to F:\Ml files\jute disease\model\kfold-cnn-class_11.h5
# Epoch 40/100
# 10/10 [==============================] - 3s 278ms/step - loss: 0.0890 - accuracy: 0.9760 - val_loss: 0.0673 - val_accuracy: 0.9655
#
# Epoch 00040: val_loss did not improve from 0.01703
# Epoch 41/100
# 10/10 [==============================] - 3s 310ms/step - loss: 0.3684 - accuracy: 0.8808 - val_loss: 0.1892 - val_accuracy: 0.9448
#
# Epoch 00041: val_loss did not improve from 0.01703
# Epoch 42/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.2218 - accuracy: 0.9173 - val_loss: 0.0909 - val_accuracy: 0.9931
#
# Epoch 00042: val_loss did not improve from 0.01703
# Epoch 43/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.2278 - accuracy: 0.9434 - val_loss: 0.0522 - val_accuracy: 0.9931
#
# Epoch 00043: val_loss did not improve from 0.01703
# Epoch 44/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.0896 - accuracy: 0.9694 - val_loss: 0.0437 - val_accuracy: 0.9862
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00044: val_loss did not improve from 0.01703
# Epoch 45/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.0954 - accuracy: 0.9640 - val_loss: 0.0698 - val_accuracy: 0.9862
#
# Epoch 00045: val_loss did not improve from 0.01703
# Epoch 46/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.0628 - accuracy: 0.9773 - val_loss: 0.0782 - val_accuracy: 0.9793
#
# Epoch 00046: val_loss did not improve from 0.01703
# Epoch 47/100
# 10/10 [==============================] - 3s 270ms/step - loss: 0.0577 - accuracy: 0.9802 - val_loss: 0.0615 - val_accuracy: 0.9931
#
# Epoch 00047: val_loss did not improve from 0.01703
# Epoch 48/100
# 10/10 [==============================] - 3s 292ms/step - loss: 0.0577 - accuracy: 0.9815 - val_loss: 0.0605 - val_accuracy: 0.9931
#
# Epoch 00048: val_loss did not improve from 0.01703
# Epoch 49/100
# 10/10 [==============================] - 3s 305ms/step - loss: 0.0467 - accuracy: 0.9831 - val_loss: 0.0571 - val_accuracy: 0.9931
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00049: val_loss did not improve from 0.01703
# Epoch 50/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.0560 - accuracy: 0.9803 - val_loss: 0.0582 - val_accuracy: 0.9931
#
# Epoch 00050: val_loss did not improve from 0.01703
# Epoch 51/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.0515 - accuracy: 0.9859 - val_loss: 0.0584 - val_accuracy: 0.9931
#
# Epoch 00051: val_loss did not improve from 0.01703
# Epoch 52/100
# 10/10 [==============================] - 3s 298ms/step - loss: 0.0473 - accuracy: 0.9876 - val_loss: 0.0577 - val_accuracy: 0.9931
#
# Epoch 00052: val_loss did not improve from 0.01703
# Epoch 53/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.0460 - accuracy: 0.9816 - val_loss: 0.0559 - val_accuracy: 0.9931
#
# Epoch 00053: val_loss did not improve from 0.01703
# Epoch 54/100
# 10/10 [==============================] - 3s 310ms/step - loss: 0.0493 - accuracy: 0.9824 - val_loss: 0.0551 - val_accuracy: 0.9931
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00054: val_loss did not improve from 0.01703
# Epoch 00054: early stopping
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0551 - accuracy: 0.9931
# Val Score:  [0.05511004850268364, 0.9931034445762634]
# ====================================================================================
#
#
# Training on Fold:  4
# Epoch 1/100
# 10/10 [==============================] - 3s 280ms/step - loss: 2.7811 - accuracy: 0.3415 - val_loss: 1.0913 - val_accuracy: 0.3448
#
# Epoch 00001: val_loss did not improve from 0.01703
# Epoch 2/100
# 10/10 [==============================] - 3s 296ms/step - loss: 1.0840 - accuracy: 0.4032 - val_loss: 0.9522 - val_accuracy: 0.6207
#
# Epoch 00002: val_loss did not improve from 0.01703
# Epoch 3/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.8835 - accuracy: 0.6329 - val_loss: 0.6350 - val_accuracy: 0.7241
#
# Epoch 00003: val_loss did not improve from 0.01703
# Epoch 4/100
# 10/10 [==============================] - 3s 307ms/step - loss: 0.6405 - accuracy: 0.7333 - val_loss: 0.5840 - val_accuracy: 0.7241
#
# Epoch 00004: val_loss did not improve from 0.01703
# Epoch 5/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.5951 - accuracy: 0.7771 - val_loss: 0.5207 - val_accuracy: 0.8000
#
# Epoch 00005: val_loss did not improve from 0.01703
# Epoch 6/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.5296 - accuracy: 0.7938 - val_loss: 0.5249 - val_accuracy: 0.8759
#
# Epoch 00006: val_loss did not improve from 0.01703
# Epoch 7/100
# 10/10 [==============================] - 3s 278ms/step - loss: 0.4910 - accuracy: 0.8104 - val_loss: 0.4308 - val_accuracy: 0.8759
#
# Epoch 00007: val_loss did not improve from 0.01703
# Epoch 8/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.4660 - accuracy: 0.8160 - val_loss: 0.3783 - val_accuracy: 0.8966
#
# Epoch 00008: val_loss did not improve from 0.01703
# Epoch 9/100
# 10/10 [==============================] - 3s 293ms/step - loss: 0.4531 - accuracy: 0.8283 - val_loss: 0.3774 - val_accuracy: 0.8828
#
# Epoch 00009: val_loss did not improve from 0.01703
# Epoch 10/100
# 10/10 [==============================] - 3s 278ms/step - loss: 0.4024 - accuracy: 0.8391 - val_loss: 0.3643 - val_accuracy: 0.8966
#
# Epoch 00010: val_loss did not improve from 0.01703
# Epoch 11/100
# 10/10 [==============================] - 3s 277ms/step - loss: 0.4296 - accuracy: 0.8370 - val_loss: 0.3224 - val_accuracy: 0.9034
#
# Epoch 00011: val_loss did not improve from 0.01703
# Epoch 12/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.3490 - accuracy: 0.8675 - val_loss: 0.3120 - val_accuracy: 0.8828
#
# Epoch 00012: val_loss did not improve from 0.01703
# Epoch 13/100
# 10/10 [==============================] - 3s 292ms/step - loss: 0.3362 - accuracy: 0.8602 - val_loss: 0.2633 - val_accuracy: 0.9103
#
# Epoch 00013: val_loss did not improve from 0.01703
# Epoch 14/100
# 10/10 [==============================] - 3s 294ms/step - loss: 0.3062 - accuracy: 0.8926 - val_loss: 0.2941 - val_accuracy: 0.9034
#
# Epoch 00014: val_loss did not improve from 0.01703
# Epoch 15/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.3495 - accuracy: 0.8657 - val_loss: 0.2530 - val_accuracy: 0.8966
#
# Epoch 00015: val_loss did not improve from 0.01703
# Epoch 16/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.3114 - accuracy: 0.8846 - val_loss: 0.2680 - val_accuracy: 0.9103
#
# Epoch 00016: val_loss did not improve from 0.01703
# Epoch 17/100
# 10/10 [==============================] - 3s 294ms/step - loss: 0.2922 - accuracy: 0.8868 - val_loss: 0.3122 - val_accuracy: 0.8759
#
# Epoch 00017: val_loss did not improve from 0.01703
# Epoch 18/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.2978 - accuracy: 0.8772 - val_loss: 0.2273 - val_accuracy: 0.9103
#
# Epoch 00018: val_loss did not improve from 0.01703
# Epoch 19/100
# 10/10 [==============================] - 3s 291ms/step - loss: 0.2160 - accuracy: 0.9170 - val_loss: 0.1942 - val_accuracy: 0.9448
#
# Epoch 00019: val_loss did not improve from 0.01703
# Epoch 20/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.2409 - accuracy: 0.9091 - val_loss: 0.2381 - val_accuracy: 0.9103
#
# Epoch 00020: val_loss did not improve from 0.01703
# Epoch 21/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.2004 - accuracy: 0.9285 - val_loss: 0.2213 - val_accuracy: 0.9103
#
# Epoch 00021: val_loss did not improve from 0.01703
# Epoch 22/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.1783 - accuracy: 0.9482 - val_loss: 0.1535 - val_accuracy: 0.9586
#
# Epoch 00022: val_loss did not improve from 0.01703
# Epoch 23/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.1852 - accuracy: 0.9313 - val_loss: 0.4029 - val_accuracy: 0.8483
#
# Epoch 00023: val_loss did not improve from 0.01703
# Epoch 24/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.2394 - accuracy: 0.9166 - val_loss: 0.2040 - val_accuracy: 0.9310
#
# Epoch 00024: val_loss did not improve from 0.01703
# Epoch 25/100
# 10/10 [==============================] - 3s 309ms/step - loss: 0.3664 - accuracy: 0.8851 - val_loss: 0.2708 - val_accuracy: 0.9172
#
# Epoch 00025: val_loss did not improve from 0.01703
# Epoch 26/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.2507 - accuracy: 0.9139 - val_loss: 0.2002 - val_accuracy: 0.9310
#
# Epoch 00026: val_loss did not improve from 0.01703
# Epoch 27/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.1913 - accuracy: 0.9436 - val_loss: 0.1515 - val_accuracy: 0.9724
#
# Epoch 00027: val_loss did not improve from 0.01703
# Epoch 28/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.2681 - accuracy: 0.9158 - val_loss: 0.1200 - val_accuracy: 0.9724
#
# Epoch 00028: val_loss did not improve from 0.01703
# Epoch 29/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.1461 - accuracy: 0.9662 - val_loss: 0.0910 - val_accuracy: 0.9724
#
# Epoch 00029: val_loss did not improve from 0.01703
# Epoch 30/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.1184 - accuracy: 0.9706 - val_loss: 0.1748 - val_accuracy: 0.9241
#
# Epoch 00030: val_loss did not improve from 0.01703
# Epoch 31/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.1076 - accuracy: 0.9610 - val_loss: 0.1142 - val_accuracy: 0.9586
#
# Epoch 00031: val_loss did not improve from 0.01703
# Epoch 32/100
# 10/10 [==============================] - 3s 310ms/step - loss: 0.1402 - accuracy: 0.9490 - val_loss: 0.0528 - val_accuracy: 0.9862
#
# Epoch 00032: val_loss did not improve from 0.01703
# Epoch 33/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.0723 - accuracy: 0.9778 - val_loss: 0.0803 - val_accuracy: 0.9586
#
# Epoch 00033: val_loss did not improve from 0.01703
# Epoch 34/100
# 10/10 [==============================] - 3s 277ms/step - loss: 0.1079 - accuracy: 0.9658 - val_loss: 0.2452 - val_accuracy: 0.9172
#
# Epoch 00034: val_loss did not improve from 0.01703
# Epoch 35/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.5317 - accuracy: 0.8369 - val_loss: 0.2795 - val_accuracy: 0.9103
#
# Epoch 00035: val_loss did not improve from 0.01703
# Epoch 36/100
# 10/10 [==============================] - 3s 295ms/step - loss: 0.3743 - accuracy: 0.8605 - val_loss: 0.2068 - val_accuracy: 0.9379
#
# Epoch 00036: val_loss did not improve from 0.01703
# Epoch 37/100
# 10/10 [==============================] - 3s 294ms/step - loss: 0.3602 - accuracy: 0.8660 - val_loss: 0.2735 - val_accuracy: 0.9310
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00037: val_loss did not improve from 0.01703
# Epoch 38/100
# 10/10 [==============================] - 3s 265ms/step - loss: 0.3452 - accuracy: 0.8621 - val_loss: 0.2451 - val_accuracy: 0.9241
#
# Epoch 00038: val_loss did not improve from 0.01703
# Epoch 39/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.2922 - accuracy: 0.9034 - val_loss: 0.2369 - val_accuracy: 0.9103
#
# Epoch 00039: val_loss did not improve from 0.01703
# Epoch 40/100
# 10/10 [==============================] - 3s 269ms/step - loss: 0.2899 - accuracy: 0.8936 - val_loss: 0.2151 - val_accuracy: 0.9241
#
# Epoch 00040: val_loss did not improve from 0.01703
# Epoch 41/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.2698 - accuracy: 0.8911 - val_loss: 0.1990 - val_accuracy: 0.9310
#
# Epoch 00041: val_loss did not improve from 0.01703
# Epoch 42/100
# 10/10 [==============================] - 3s 293ms/step - loss: 0.2207 - accuracy: 0.9194 - val_loss: 0.1789 - val_accuracy: 0.9448
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00042: val_loss did not improve from 0.01703
# Epoch 43/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.2396 - accuracy: 0.9144 - val_loss: 0.1774 - val_accuracy: 0.9448
#
# Epoch 00043: val_loss did not improve from 0.01703
# Epoch 44/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.2130 - accuracy: 0.9260 - val_loss: 0.1767 - val_accuracy: 0.9448
#
# Epoch 00044: val_loss did not improve from 0.01703
# Epoch 45/100
# 10/10 [==============================] - 3s 309ms/step - loss: 0.2214 - accuracy: 0.9218 - val_loss: 0.1770 - val_accuracy: 0.9448
#
# Epoch 00045: val_loss did not improve from 0.01703
# Epoch 46/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.2117 - accuracy: 0.9273 - val_loss: 0.1769 - val_accuracy: 0.9448
#
# Epoch 00046: val_loss did not improve from 0.01703
# Epoch 47/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.2397 - accuracy: 0.9169 - val_loss: 0.1764 - val_accuracy: 0.9448
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00047: val_loss did not improve from 0.01703
# Epoch 00047: early stopping
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1764 - accuracy: 0.9448
# Val Score:  [0.17640814185142517, 0.9448275566101074]
# ====================================================================================
#
#
# Training on Fold:  5
# Epoch 1/100
# 10/10 [==============================] - 3s 283ms/step - loss: 2.4460 - accuracy: 0.3205 - val_loss: 1.0934 - val_accuracy: 0.3034
#
# Epoch 00001: val_loss did not improve from 0.01703
# Epoch 2/100
# 10/10 [==============================] - 3s 282ms/step - loss: 1.0652 - accuracy: 0.4319 - val_loss: 0.9410 - val_accuracy: 0.4138
#
# Epoch 00002: val_loss did not improve from 0.01703
# Epoch 3/100
# 10/10 [==============================] - 3s 263ms/step - loss: 0.8701 - accuracy: 0.5768 - val_loss: 1.0763 - val_accuracy: 0.3862
#
# Epoch 00003: val_loss did not improve from 0.01703
# Epoch 4/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.6457 - accuracy: 0.6972 - val_loss: 0.7614 - val_accuracy: 0.6000
#
# Epoch 00004: val_loss did not improve from 0.01703
# Epoch 5/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.5503 - accuracy: 0.7924 - val_loss: 0.7210 - val_accuracy: 0.7172
#
# Epoch 00005: val_loss did not improve from 0.01703
# Epoch 6/100
# 10/10 [==============================] - 3s 307ms/step - loss: 0.4995 - accuracy: 0.8060 - val_loss: 0.7822 - val_accuracy: 0.6966
#
# Epoch 00006: val_loss did not improve from 0.01703
# Epoch 7/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.4359 - accuracy: 0.8467 - val_loss: 0.7170 - val_accuracy: 0.7241
#
# Epoch 00007: val_loss did not improve from 0.01703
# Epoch 8/100
# 10/10 [==============================] - 3s 307ms/step - loss: 0.3907 - accuracy: 0.8576 - val_loss: 0.5797 - val_accuracy: 0.7655
#
# Epoch 00008: val_loss did not improve from 0.01703
# Epoch 9/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.4049 - accuracy: 0.8432 - val_loss: 0.4392 - val_accuracy: 0.8414
#
# Epoch 00009: val_loss did not improve from 0.01703
# Epoch 10/100
# 10/10 [==============================] - 3s 296ms/step - loss: 0.3940 - accuracy: 0.8562 - val_loss: 0.4439 - val_accuracy: 0.8207
#
# Epoch 00010: val_loss did not improve from 0.01703
# Epoch 11/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.3665 - accuracy: 0.8618 - val_loss: 0.4383 - val_accuracy: 0.8276
#
# Epoch 00011: val_loss did not improve from 0.01703
# Epoch 12/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.3554 - accuracy: 0.8790 - val_loss: 0.3943 - val_accuracy: 0.8621
#
# Epoch 00012: val_loss did not improve from 0.01703
# Epoch 13/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.4368 - accuracy: 0.8275 - val_loss: 0.3833 - val_accuracy: 0.8552
#
# Epoch 00013: val_loss did not improve from 0.01703
# Epoch 14/100
# 10/10 [==============================] - 3s 291ms/step - loss: 0.3270 - accuracy: 0.8904 - val_loss: 0.4007 - val_accuracy: 0.8483
#
# Epoch 00014: val_loss did not improve from 0.01703
# Epoch 15/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.3657 - accuracy: 0.8798 - val_loss: 0.3701 - val_accuracy: 0.8414
#
# Epoch 00015: val_loss did not improve from 0.01703
# Epoch 16/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.3123 - accuracy: 0.8924 - val_loss: 0.2866 - val_accuracy: 0.8897
#
# Epoch 00016: val_loss did not improve from 0.01703
# Epoch 17/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.2970 - accuracy: 0.8933 - val_loss: 0.2407 - val_accuracy: 0.9103
#
# Epoch 00017: val_loss did not improve from 0.01703
# Epoch 18/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.2571 - accuracy: 0.9007 - val_loss: 0.2531 - val_accuracy: 0.8828
#
# Epoch 00018: val_loss did not improve from 0.01703
# Epoch 19/100
# 10/10 [==============================] - 3s 277ms/step - loss: 0.2810 - accuracy: 0.8967 - val_loss: 0.5211 - val_accuracy: 0.8069
#
# Epoch 00019: val_loss did not improve from 0.01703
# Epoch 20/100
# 10/10 [==============================] - 3s 307ms/step - loss: 0.3792 - accuracy: 0.8747 - val_loss: 0.3309 - val_accuracy: 0.8759
#
# Epoch 00020: val_loss did not improve from 0.01703
# Epoch 21/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.2825 - accuracy: 0.9018 - val_loss: 0.2483 - val_accuracy: 0.8966
#
# Epoch 00021: val_loss did not improve from 0.01703
# Epoch 22/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.2720 - accuracy: 0.9103 - val_loss: 0.2009 - val_accuracy: 0.9310
#
# Epoch 00022: val_loss did not improve from 0.01703
# Epoch 23/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.2066 - accuracy: 0.9331 - val_loss: 0.2073 - val_accuracy: 0.9034
#
# Epoch 00023: val_loss did not improve from 0.01703
# Epoch 24/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.2060 - accuracy: 0.9243 - val_loss: 0.1457 - val_accuracy: 0.9448
#
# Epoch 00024: val_loss did not improve from 0.01703
# Epoch 25/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.1497 - accuracy: 0.9381 - val_loss: 0.1398 - val_accuracy: 0.9655
#
# Epoch 00025: val_loss did not improve from 0.01703
# Epoch 26/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.1490 - accuracy: 0.9470 - val_loss: 0.1070 - val_accuracy: 0.9655
#
# Epoch 00026: val_loss did not improve from 0.01703
# Epoch 27/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.1270 - accuracy: 0.9566 - val_loss: 0.0991 - val_accuracy: 0.9586
#
# Epoch 00027: val_loss did not improve from 0.01703
# Epoch 28/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.1241 - accuracy: 0.9640 - val_loss: 0.1018 - val_accuracy: 0.9379
#
# Epoch 00028: val_loss did not improve from 0.01703
# Epoch 29/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.1146 - accuracy: 0.9682 - val_loss: 0.0808 - val_accuracy: 0.9793
#
# Epoch 00029: val_loss did not improve from 0.01703
# Epoch 30/100
# 10/10 [==============================] - 3s 287ms/step - loss: 0.0841 - accuracy: 0.9718 - val_loss: 0.0586 - val_accuracy: 0.9862
#
# Epoch 00030: val_loss did not improve from 0.01703
# Epoch 31/100
# 10/10 [==============================] - 3s 306ms/step - loss: 0.0976 - accuracy: 0.9693 - val_loss: 0.1227 - val_accuracy: 0.9724
#
# Epoch 00031: val_loss did not improve from 0.01703
# Epoch 32/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.1831 - accuracy: 0.9337 - val_loss: 0.0963 - val_accuracy: 0.9517
#
# Epoch 00032: val_loss did not improve from 0.01703
# Epoch 33/100
# 10/10 [==============================] - 3s 287ms/step - loss: 0.1129 - accuracy: 0.9704 - val_loss: 0.0869 - val_accuracy: 0.9586
#
# Epoch 00033: val_loss did not improve from 0.01703
# Epoch 34/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.0830 - accuracy: 0.9747 - val_loss: 0.1011 - val_accuracy: 0.9586
#
# Epoch 00034: val_loss did not improve from 0.01703
# Epoch 35/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.0940 - accuracy: 0.9705 - val_loss: 0.1697 - val_accuracy: 0.9172
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00035: val_loss did not improve from 0.01703
# Epoch 36/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.1328 - accuracy: 0.9499 - val_loss: 0.0488 - val_accuracy: 0.9931
#
# Epoch 00036: val_loss did not improve from 0.01703
# Epoch 37/100
# 10/10 [==============================] - 3s 268ms/step - loss: 0.0517 - accuracy: 0.9896 - val_loss: 0.0538 - val_accuracy: 0.9862
# Epoch 00037: val_loss did not improve from 0.01703
# Epoch 38/100
# 10/10 [==============================] - 3s 287ms/step - loss: 0.0441 - accuracy: 0.9853 - val_loss: 0.0475 - val_accuracy: 0.9862
#
# Epoch 00038: val_loss did not improve from 0.01703
# Epoch 39/100
# 10/10 [==============================] - 3s 296ms/step - loss: 0.0397 - accuracy: 0.9858 - val_loss: 0.0399 - val_accuracy: 0.9931
#
# Epoch 00039: val_loss did not improve from 0.01703
# Epoch 40/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.0346 - accuracy: 0.9908 - val_loss: 0.0440 - val_accuracy: 0.9862
#
# Epoch 00040: val_loss did not improve from 0.01703
# Epoch 41/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.0298 - accuracy: 0.9933 - val_loss: 0.0393 - val_accuracy: 0.9931
#
# Epoch 00041: val_loss did not improve from 0.01703
# Epoch 42/100
# 10/10 [==============================] - 3s 284ms/step - loss: 0.0432 - accuracy: 0.9838 - val_loss: 0.0390 - val_accuracy: 0.9931
#
# Epoch 00042: val_loss did not improve from 0.01703
# Epoch 43/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.0343 - accuracy: 0.9879 - val_loss: 0.0392 - val_accuracy: 0.9862
#
# Epoch 00043: val_loss did not improve from 0.01703
# Epoch 44/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.0379 - accuracy: 0.9888 - val_loss: 0.0443 - val_accuracy: 0.9862
#
# Epoch 00044: val_loss did not improve from 0.01703
# Epoch 45/100
# 10/10 [==============================] - 3s 310ms/step - loss: 0.0281 - accuracy: 0.9941 - val_loss: 0.0338 - val_accuracy: 0.9931
#
# Epoch 00045: val_loss did not improve from 0.01703
# Epoch 46/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.0309 - accuracy: 0.9925 - val_loss: 0.0361 - val_accuracy: 0.9931
#
# Epoch 00046: val_loss did not improve from 0.01703
# Epoch 47/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.0238 - accuracy: 0.9944 - val_loss: 0.0343 - val_accuracy: 0.9931
#
# Epoch 00047: val_loss did not improve from 0.01703
# Epoch 48/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.0197 - accuracy: 0.9940 - val_loss: 0.0323 - val_accuracy: 0.9931
#
# Epoch 00048: val_loss did not improve from 0.01703
# Epoch 49/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.0289 - accuracy: 0.9919 - val_loss: 0.0349 - val_accuracy: 0.9931
#
# Epoch 00049: val_loss did not improve from 0.01703
# Epoch 50/100
# 10/10 [==============================] - 3s 268ms/step - loss: 0.0295 - accuracy: 0.9905 - val_loss: 0.0338 - val_accuracy: 0.9931
#
# Epoch 00050: val_loss did not improve from 0.01703
# Epoch 51/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.0299 - accuracy: 0.9897 - val_loss: 0.0366 - val_accuracy: 0.9862
#
# Epoch 00051: val_loss did not improve from 0.01703
# Epoch 52/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.0148 - accuracy: 0.9979 - val_loss: 0.0352 - val_accuracy: 0.9862
#
# Epoch 00052: val_loss did not improve from 0.01703
# Epoch 53/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.0292 - accuracy: 0.9904 - val_loss: 0.0361 - val_accuracy: 0.9931
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00053: val_loss did not improve from 0.01703
# Epoch 54/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.0285 - accuracy: 0.9965 - val_loss: 0.0367 - val_accuracy: 0.9862
#
# Epoch 00054: val_loss did not improve from 0.01703
# Epoch 55/100
# 10/10 [==============================] - 3s 286ms/step - loss: 0.0298 - accuracy: 0.9898 - val_loss: 0.0367 - val_accuracy: 0.9862
#
# Epoch 00055: val_loss did not improve from 0.01703
# Epoch 56/100
# 10/10 [==============================] - 3s 283ms/step - loss: 0.0168 - accuracy: 0.9963 - val_loss: 0.0371 - val_accuracy: 0.9862
#
# Epoch 00056: val_loss did not improve from 0.01703
# Epoch 57/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.0232 - accuracy: 0.9914 - val_loss: 0.0378 - val_accuracy: 0.9862
#
# Epoch 00057: val_loss did not improve from 0.01703
# Epoch 58/100
# 10/10 [==============================] - 3s 266ms/step - loss: 0.0227 - accuracy: 0.9945 - val_loss: 0.0380 - val_accuracy: 0.9862
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00058: val_loss did not improve from 0.01703
# Epoch 59/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.0252 - accuracy: 0.9929 - val_loss: 0.0379 - val_accuracy: 0.9862
#
# Epoch 00059: val_loss did not improve from 0.01703
# Epoch 60/100
# 10/10 [==============================] - 3s 279ms/step - loss: 0.0403 - accuracy: 0.9877 - val_loss: 0.0378 - val_accuracy: 0.9862
#
# Epoch 00060: val_loss did not improve from 0.01703
# Epoch 61/100
# 10/10 [==============================] - 3s 282ms/step - loss: 0.0223 - accuracy: 0.9909 - val_loss: 0.0377 - val_accuracy: 0.9862
#
# Epoch 00061: val_loss did not improve from 0.01703
# Epoch 62/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.0199 - accuracy: 0.9958 - val_loss: 0.0378 - val_accuracy: 0.9862
#
# Epoch 00062: val_loss did not improve from 0.01703
# Epoch 63/100
# 10/10 [==============================] - 3s 281ms/step - loss: 0.0246 - accuracy: 0.9953 - val_loss: 0.0377 - val_accuracy: 0.9862
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00063: val_loss did not improve from 0.01703
# Epoch 00063: early stopping
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0377 - accuracy: 0.9862
# Val Score:  [0.037701819092035294, 0.9862068891525269]
# ====================================================================================

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(15, 6))
plt.title('Train Accuracy vs Val Accuracy (CNN)')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='black', linestyle = "dashdot")
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='red', linestyle = "dashdot")
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='green', linestyle = "dashdot")
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='blue', linestyle = "dashdot")
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='c', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='c', linestyle = "dashdot")
plt.legend(prop={'size': 15},
          fancybox=True, shadow=True)
plt.show()

# %%
sns.set(font_scale=2)
sns.set_style('whitegrid')
plt.figure(figsize=(15, 6))
plt.title('Train Loss vs Val Loss (CNN)')
plt.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='black', linestyle = "dashdot")
plt.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='red', linestyle = "dashdot")
plt.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='green', linestyle = "dashdot")
plt.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='blue', linestyle = "dashdot")
plt.plot(model_history[4].history['loss'], label='Train Loss Fold 5', color='c', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss Fold 5', color='c', linestyle = "dashdot")
plt.legend(prop={'size': 15},
          fancybox=True, shadow=True)
plt.show()

# %%
#Load the model that was saved by ModelCheckpoint
nFoldCnnModel = load_model('F:\\Ml files\\jute disease\\model\\kfold-cnn-class_11.h5')
preds=nFoldCnnModel.predict(x_test)
predictions=np.argmax(preds,axis=1)

# %%
from sklearn.metrics import classification_report
Y_test =np.argmax(y_test,axis=1)
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       124
#            1       1.00      0.99      1.00       105
#            2       1.00      0.96      0.98       132
#
#     accuracy                           0.98       361
#    macro avg       0.98      0.98      0.98       361
# weighted avg       0.98      0.98      0.98       361

# %%
def report_generate(Y_test, predictions):
  report = pd.DataFrame(classification_report(y_true = Y_test, y_pred = predictions, output_dict=True)).transpose()

  report = report.rename(index={'0': 'Healthy','1':'Powdery mildew','2':'Yellow mosaic'})
  report[['precision','recall','f1-score']]=report[['precision','recall','f1-score']].apply(lambda x: round(x*100,2))
  report=report.drop(["support"],axis=1)
  columns = ['precision','recall','f1-score']
  report.columns = columns
  plt = report.plot(kind='bar',figsize=(12,6))
  
  plot=plt.tick_params(rotation=40)
  
  return plot,report

# %%
report_generate(Y_test, predictions)
# Out:
# (None,
#                  precision  recall  f1-score
#  Healthy             95.38  100.00     97.64
#  Powdery mildew     100.00   99.05     99.52
#  Yellow mosaic      100.00   96.21     98.07
#  accuracy            98.34   98.34     98.34
#  macro avg           98.46   98.42     98.41
#  weighted avg        98.41   98.34     98.34)

# %%
#confusion matrix
def conf_matrix(Y_test, y_pred):

  cm = confusion_matrix(Y_test, y_pred) 
# Transform to df for easier plotting
  
  cm_df = pd.DataFrame(cm,
                       index = ['Healthy', 'Powdery mildew', 'Yellow mosaic'], 
                       columns = ['Healthy', 'Powdery mildew', 'Yellow mosaic'])
  plt.figure(figsize=(10,7))
  sns.heatmap(cm_df, annot=True,cmap="YlGnBu", fmt='g')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.xticks(rotation = 45)
  plt.yticks(rotation = 45)
  plt.show()
  plt.close()

# %%
conf_matrix(Y_test,predictions)

# %%
# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(categories):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)

print('ROC AUC score:', multiclass_roc_auc_score(Y_test,predictions))

c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
plt.show()
# Out:
# ROC AUC score: 0.9878801578168667

# %%
sns.set(font_scale=1)
correct_class=[]
incorrect_class=[]
i=0
for i in range(len(y_test)):
    if(np.argmax(y_test[i])==predictions[i]):
        correct_class.append(i)
    if(len(correct_class)==8):
        break

count=0
fig,ax=plt.subplots(4,2)
fig.set_size_inches(15,15)
for i in range (4):
    for j in range (2):
        ax[i,j].imshow(x_test[correct_class[count]])
        ax[i,j].set_title("Predicted Flower : "+ categories[predictions[correct_class[count]]] +"\n"+"Actual Flower : "+ categories[np.argmax(y_test[correct_class[count]])])
        plt.tight_layout()
        count+=1

# %%
i=0
for i in range(len(y_test)):
    
    if (np.argmax(y_test[i])!=predictions[i]):
        
        incorrect_class.append(i)
    if (len(incorrect_class)==8):
        break

# %%
count=0
fig,ax=plt.subplots(2,2)
fig.set_size_inches(8,5)
for i in range(2):
    for j in range(2):
        ax[i,j].imshow(x_test[incorrect_class[count]])
        ax[i,j].set_title("Predicted flower : " + categories[predictions[incorrect_class[count]]] + "\n"+"Actual Flower : " +categories[np.argmax(y_test[incorrect_class[count]])])
        plt.tight_layout()
        count+=1

# %% [markdown]
# # VGG16

# %%
def vgg_model(input_shape):
    Base_model = VGG16(include_top= False, weights='imagenet',input_shape = (input_shape), pooling='avg')
    VGG16_model = Sequential()
    VGG16_model.add(Base_model)
    VGG16_model.add(Dense(256,activation='relu'))
    # adding prediction(softmax) layer
    VGG16_model.add(Dense(3,activation="softmax"))
    VGG16_model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
    VGG16_model.summary()
    return VGG16_model

# %%
#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=50, BATCH_SIZE=128):
    model = None
    input_shape = 150,150,3
    model = vgg_model(input_shape)
    results = model.fit_generator(datagen.flow(t_x, t_y, batch_size=BATCH_SIZE),
                              epochs = EPOCHS, validation_data = (val_x,val_y),
                              callbacks= callbacks,
                              verbose = 1, steps_per_epoch= t_x.shape[0] // 128)
    
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
checkpoint_path = 'F:\\Ml files\\jute disease\\model\\K-fold-11_VGG16.h5'
callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', patience=15, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint(monitor='val_loss', mode='min', filepath=checkpoint_path, verbose=1, save_best_only=True, save_weights_only=False),
    acc_callback
]

# %%
n_folds=5
epochs = 100
batch_size = 128

VGG_model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    VGG_model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 512)               14714688
# _________________________________________________________________
# dense_17 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 14,846,787
# Trainable params: 14,846,787
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 81s 8s/step - loss: 4.4174 - accuracy: 0.3397 - val_loss: 1.1623 - val_accuracy: 0.3103
#
# Epoch 00001: val_loss improved from inf to 1.16232, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 2/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.1962 - accuracy: 0.3477 - val_loss: 1.1026 - val_accuracy: 0.2690
#
# Epoch 00002: val_loss improved from 1.16232 to 1.10258, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 3/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.0966 - accuracy: 0.3244 - val_loss: 1.1031 - val_accuracy: 0.3379
#
# Epoch 00003: val_loss did not improve from 1.10258
# Epoch 4/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.0990 - accuracy: 0.3715 - val_loss: 1.0869 - val_accuracy: 0.3379
#
# Epoch 00004: val_loss improved from 1.10258 to 1.08690, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 5/100
# 10/10 [==============================] - 49s 5s/step - loss: 1.0894 - accuracy: 0.3645 - val_loss: 1.0690 - val_accuracy: 0.4759
#
# Epoch 00005: val_loss improved from 1.08690 to 1.06904, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 6/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.0827 - accuracy: 0.3820 - val_loss: 1.0348 - val_accuracy: 0.5793
#
# Epoch 00006: val_loss improved from 1.06904 to 1.03478, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 7/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.1066 - accuracy: 0.4055 - val_loss: 1.0968 - val_accuracy: 0.3379
#
# Epoch 00007: val_loss did not improve from 1.03478
# Epoch 8/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.0883 - accuracy: 0.3702 - val_loss: 1.1327 - val_accuracy: 0.3379
#
# Epoch 00008: val_loss did not improve from 1.03478
# Epoch 9/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.1032 - accuracy: 0.3374 - val_loss: 1.0930 - val_accuracy: 0.2690
#
# Epoch 00009: val_loss did not improve from 1.03478
# Epoch 10/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.0511 - accuracy: 0.4267 - val_loss: 0.8947 - val_accuracy: 0.6759
#
# Epoch 00010: val_loss improved from 1.03478 to 0.89466, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 11/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.0608 - accuracy: 0.4394 - val_loss: 0.9727 - val_accuracy: 0.6069
#
# Epoch 00011: val_loss did not improve from 0.89466
# Epoch 12/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0026 - accuracy: 0.4584 - val_loss: 1.1053 - val_accuracy: 0.3586
#
# Epoch 00012: val_loss did not improve from 0.89466
# Epoch 13/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8817 - accuracy: 0.5515 - val_loss: 0.7093 - val_accuracy: 0.6483
#
# Epoch 00013: val_loss improved from 0.89466 to 0.70930, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 14/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.7760 - accuracy: 0.6443 - val_loss: 0.5868 - val_accuracy: 0.7862
#
# Epoch 00014: val_loss improved from 0.70930 to 0.58680, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 15/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.6099 - accuracy: 0.7112 - val_loss: 2.1761 - val_accuracy: 0.3517
#
# Epoch 00015: val_loss did not improve from 0.58680
# Epoch 16/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9578 - accuracy: 0.5976 - val_loss: 0.5088 - val_accuracy: 0.7724
#
# Epoch 00016: val_loss improved from 0.58680 to 0.50883, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 17/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.4446 - accuracy: 0.8128 - val_loss: 0.5426 - val_accuracy: 0.7448
#
# Epoch 00017: val_loss did not improve from 0.50883
# Epoch 18/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.4465 - accuracy: 0.8488 - val_loss: 0.7616 - val_accuracy: 0.5586
#
# Epoch 00018: val_loss did not improve from 0.50883
# Epoch 19/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.5481 - accuracy: 0.7562 - val_loss: 0.2206 - val_accuracy: 0.9517
#
# Epoch 00019: val_loss improved from 0.50883 to 0.22057, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 20/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.2981 - accuracy: 0.9145 - val_loss: 0.2157 - val_accuracy: 0.9310
#
# Epoch 00020: val_loss improved from 0.22057 to 0.21571, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 21/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.1979 - accuracy: 0.9321 - val_loss: 0.0981 - val_accuracy: 0.9586
#
# Epoch 00021: val_loss improved from 0.21571 to 0.09813, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 22/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.2198 - accuracy: 0.9349 - val_loss: 0.0599 - val_accuracy: 0.9862
#
# Epoch 00022: val_loss improved from 0.09813 to 0.05987, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 23/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.1610 - accuracy: 0.9462 - val_loss: 0.0484 - val_accuracy: 0.9793
#
# Epoch 00023: val_loss improved from 0.05987 to 0.04844, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 24/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0846 - accuracy: 0.9769 - val_loss: 0.0548 - val_accuracy: 0.9724
#
# Epoch 00024: val_loss did not improve from 0.04844
# Epoch 25/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.1217 - accuracy: 0.9650 - val_loss: 0.0508 - val_accuracy: 0.9793
#
# Epoch 00025: val_loss did not improve from 0.04844
# Epoch 26/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0876 - accuracy: 0.9731 - val_loss: 0.1283 - val_accuracy: 0.9655
#
# Epoch 00026: val_loss did not improve from 0.04844
# Epoch 27/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.2484 - accuracy: 0.9324 - val_loss: 0.1724 - val_accuracy: 0.9724
#
# Epoch 00027: val_loss did not improve from 0.04844
# Epoch 28/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.3224 - accuracy: 0.8961 - val_loss: 0.2403 - val_accuracy: 0.9517
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00028: val_loss did not improve from 0.04844
# Epoch 29/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.3050 - accuracy: 0.8946 - val_loss: 0.1470 - val_accuracy: 0.9724
#
# Epoch 00029: val_loss did not improve from 0.04844
# Epoch 30/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.1685 - accuracy: 0.9524 - val_loss: 0.1085 - val_accuracy: 0.9793
#
# Epoch 00030: val_loss did not improve from 0.04844
# Epoch 31/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.1190 - accuracy: 0.9740 - val_loss: 0.0688 - val_accuracy: 0.9793
#
# Epoch 00031: val_loss did not improve from 0.04844
# Epoch 32/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0914 - accuracy: 0.9722 - val_loss: 0.0396 - val_accuracy: 0.9931
#
# Epoch 00032: val_loss improved from 0.04844 to 0.03965, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 33/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0966 - accuracy: 0.9694 - val_loss: 0.0280 - val_accuracy: 0.9931
#
# Epoch 00033: val_loss improved from 0.03965 to 0.02796, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 34/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0785 - accuracy: 0.9769 - val_loss: 0.0230 - val_accuracy: 0.9931
#
# Epoch 00034: val_loss improved from 0.02796 to 0.02303, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 35/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0433 - accuracy: 0.9866 - val_loss: 0.0187 - val_accuracy: 0.9931
#
# Epoch 00035: val_loss improved from 0.02303 to 0.01871, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 36/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.0422 - accuracy: 0.9869 - val_loss: 0.0158 - val_accuracy: 1.0000
#
# Epoch 00036: val_loss improved from 0.01871 to 0.01577, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 37/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0454 - accuracy: 0.9852 - val_loss: 0.0175 - val_accuracy: 0.9931
#
# Epoch 00037: val_loss did not improve from 0.01577
# Epoch 38/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0286 - accuracy: 0.9911 - val_loss: 0.0139 - val_accuracy: 1.0000
#
# Epoch 00038: val_loss improved from 0.01577 to 0.01392, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 39/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.0363 - accuracy: 0.9851 - val_loss: 0.0178 - val_accuracy: 0.9931
#
# Epoch 00039: val_loss did not improve from 0.01392
# Epoch 40/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0298 - accuracy: 0.9894 - val_loss: 0.0070 - val_accuracy: 1.0000
#
# Epoch 00040: val_loss improved from 0.01392 to 0.00696, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 41/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0307 - accuracy: 0.9939 - val_loss: 0.0105 - val_accuracy: 0.9931
#
# Epoch 00041: val_loss did not improve from 0.00696
# Epoch 42/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0202 - accuracy: 0.9907 - val_loss: 0.0173 - val_accuracy: 0.9931
#
# Epoch 00042: val_loss did not improve from 0.00696
# Epoch 43/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0352 - accuracy: 0.9888 - val_loss: 0.0044 - val_accuracy: 1.0000
#
# Epoch 00043: val_loss improved from 0.00696 to 0.00443, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 44/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0446 - accuracy: 0.9803 - val_loss: 0.0205 - val_accuracy: 0.9862
#
# Epoch 00044: val_loss did not improve from 0.00443
# Epoch 45/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0270 - accuracy: 0.9910 - val_loss: 0.0069 - val_accuracy: 1.0000
#
# Epoch 00045: val_loss did not improve from 0.00443
# Epoch 46/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0282 - accuracy: 0.9904 - val_loss: 0.0187 - val_accuracy: 0.9862
#
# Epoch 00046: val_loss did not improve from 0.00443
# Epoch 47/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0219 - accuracy: 0.9931 - val_loss: 0.0013 - val_accuracy: 1.0000
#
# Epoch 00047: val_loss improved from 0.00443 to 0.00134, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 48/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0121 - accuracy: 0.9967 - val_loss: 0.0011 - val_accuracy: 1.0000
#
# Epoch 00048: val_loss improved from 0.00134 to 0.00111, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 49/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.0155 - accuracy: 0.9960 - val_loss: 0.0071 - val_accuracy: 0.9931
#
# Epoch 00049: val_loss did not improve from 0.00111
# Epoch 50/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0210 - accuracy: 0.9889 - val_loss: 7.0878e-04 - val_accuracy: 1.0000
#
# Epoch 00050: val_loss improved from 0.00111 to 0.00071, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 51/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0065 - accuracy: 0.9966 - val_loss: 0.0043 - val_accuracy: 1.0000
#
# Epoch 00051: val_loss did not improve from 0.00071
# Epoch 52/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0137 - accuracy: 0.9949 - val_loss: 7.3379e-04 - val_accuracy: 1.0000
#
# Epoch 00052: val_loss did not improve from 0.00071
# Epoch 53/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0060 - accuracy: 0.9993 - val_loss: 0.0015 - val_accuracy: 1.0000
#
# Epoch 00053: val_loss did not improve from 0.00071
# Epoch 54/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0152 - accuracy: 0.9939 - val_loss: 2.9814e-04 - val_accuracy: 1.0000
#
# Epoch 00054: val_loss improved from 0.00071 to 0.00030, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 55/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0092 - accuracy: 0.9964 - val_loss: 5.9350e-04 - val_accuracy: 1.0000
#
# Epoch 00055: val_loss did not improve from 0.00030
# Epoch 56/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.0023 - val_accuracy: 1.0000
#
# Epoch 00056: val_loss did not improve from 0.00030
# Epoch 57/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0090 - accuracy: 0.9959 - val_loss: 2.5918e-04 - val_accuracy: 1.0000
#
# Epoch 00057: val_loss improved from 0.00030 to 0.00026, saving model to F:\Ml files\jute disease\model\K-fold-11_VGG16.h5
# Epoch 58/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0074 - accuracy: 0.9983 - val_loss: 9.0507e-04 - val_accuracy: 1.0000
#
# Epoch 00058: val_loss did not improve from 0.00026
# Epoch 59/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 5.4544e-04 - val_accuracy: 1.0000
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00059: val_loss did not improve from 0.00026
# Epoch 60/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 6.0956e-04 - val_accuracy: 1.0000
#
# Epoch 00060: val_loss did not improve from 0.00026
# Epoch 61/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0054 - accuracy: 0.9992 - val_loss: 5.3419e-04 - val_accuracy: 1.0000
#
# Epoch 00061: val_loss did not improve from 0.00026
# Epoch 62/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 4.1346e-04 - val_accuracy: 1.0000
#
# Epoch 00062: val_loss did not improve from 0.00026
# Epoch 63/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 3.8604e-04 - val_accuracy: 1.0000
#
# Epoch 00063: val_loss did not improve from 0.00026
# Epoch 64/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0056 - accuracy: 0.9988 - val_loss: 4.4800e-04 - val_accuracy: 1.0000
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00064: val_loss did not improve from 0.00026
# Epoch 65/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 4.5950e-04 - val_accuracy: 1.0000
#
# Epoch 00065: val_loss did not improve from 0.00026
# Epoch 66/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 4.6185e-04 - val_accuracy: 1.0000
#
# Epoch 00066: val_loss did not improve from 0.00026
# Epoch 67/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0090 - accuracy: 0.9947 - val_loss: 4.7646e-04 - val_accuracy: 1.0000
#
# Epoch 00067: val_loss did not improve from 0.00026
# Epoch 68/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0109 - accuracy: 0.9968 - val_loss: 4.8276e-04 - val_accuracy: 1.0000
#
# Epoch 00068: val_loss did not improve from 0.00026
# Epoch 69/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0060 - accuracy: 0.9966 - val_loss: 4.8930e-04 - val_accuracy: 1.0000
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00069: val_loss did not improve from 0.00026
# Epoch 70/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 5.0043e-04 - val_accuracy: 1.0000
#
# Epoch 00070: val_loss did not improve from 0.00026
# Epoch 71/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0067 - accuracy: 0.9986 - val_loss: 4.9188e-04 - val_accuracy: 1.0000
#
# Epoch 00071: val_loss did not improve from 0.00026
# Epoch 72/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0091 - accuracy: 0.9974 - val_loss: 4.8297e-04 - val_accuracy: 1.0000
#
# Epoch 00072: val_loss did not improve from 0.00026
# Epoch 00072: early stopping
# 5/5 [==============================] - 5s 903ms/step - loss: 4.8297e-04 - accuracy: 1.0000
# Val Score:  [0.00048297145985998213, 1.0]
# ====================================================================================
#
#
# Training on Fold:  2
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 512)               14714688
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 14,846,787
# Trainable params: 14,846,787
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 46s 4s/step - loss: 2.1647 - accuracy: 0.2923 - val_loss: 1.1394 - val_accuracy: 0.3172
#
# Epoch 00001: val_loss did not improve from 0.00026
# Epoch 2/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.1104 - accuracy: 0.3555 - val_loss: 1.0958 - val_accuracy: 0.3103
#
# Epoch 00002: val_loss did not improve from 0.00026
# Epoch 3/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.1061 - accuracy: 0.3318 - val_loss: 1.0993 - val_accuracy: 0.5241
#
# Epoch 00003: val_loss did not improve from 0.00026
# Epoch 4/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0755 - accuracy: 0.4207 - val_loss: 0.9755 - val_accuracy: 0.6759
#
# Epoch 00004: val_loss did not improve from 0.00026
# Epoch 5/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0269 - accuracy: 0.4752 - val_loss: 0.6479 - val_accuracy: 0.6345
#
# Epoch 00005: val_loss did not improve from 0.00026
# Epoch 6/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.7027 - accuracy: 0.6091 - val_loss: 0.8158 - val_accuracy: 0.5655
#
# Epoch 00006: val_loss did not improve from 0.00026
# Epoch 7/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.7811 - accuracy: 0.5667 - val_loss: 0.5299 - val_accuracy: 0.6828
#
# Epoch 00007: val_loss did not improve from 0.00026
# Epoch 8/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.6178 - accuracy: 0.6199 - val_loss: 0.4594 - val_accuracy: 0.7103
#
# Epoch 00008: val_loss did not improve from 0.00026
# Epoch 9/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.6014 - accuracy: 0.6549 - val_loss: 0.4456 - val_accuracy: 0.8069
#
# Epoch 00009: val_loss did not improve from 0.00026
# Epoch 10/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.6366 - accuracy: 0.6472 - val_loss: 0.4593 - val_accuracy: 0.7241
#
# Epoch 00010: val_loss did not improve from 0.00026
# Epoch 11/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.5707 - accuracy: 0.7282 - val_loss: 0.3620 - val_accuracy: 0.9034
#
# Epoch 00011: val_loss did not improve from 0.00026
# Epoch 12/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.5096 - accuracy: 0.7833 - val_loss: 0.5464 - val_accuracy: 0.7172
#
# Epoch 00012: val_loss did not improve from 0.00026
# Epoch 13/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.5918 - accuracy: 0.6841 - val_loss: 0.5022 - val_accuracy: 0.7241
#
# Epoch 00013: val_loss did not improve from 0.00026
# Epoch 14/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.5836 - accuracy: 0.6290 - val_loss: 0.4656 - val_accuracy: 0.7103
#
# Epoch 00014: val_loss did not improve from 0.00026
# Epoch 15/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.5899 - accuracy: 0.6459 - val_loss: 0.4977 - val_accuracy: 0.7586
#
# Epoch 00015: val_loss did not improve from 0.00026
# Epoch 16/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.4960 - accuracy: 0.7753 - val_loss: 0.3249 - val_accuracy: 0.8276
#
# Epoch 00016: val_loss did not improve from 0.00026
# Epoch 17/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.3818 - accuracy: 0.8302 - val_loss: 0.3554 - val_accuracy: 0.8483
#
# Epoch 00017: val_loss did not improve from 0.00026
# Epoch 18/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.4031 - accuracy: 0.8263 - val_loss: 0.3097 - val_accuracy: 0.8966
#
# Epoch 00018: val_loss did not improve from 0.00026
# Epoch 19/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.2656 - accuracy: 0.9261 - val_loss: 0.1065 - val_accuracy: 0.9655
#
# Epoch 00019: val_loss did not improve from 0.00026
# Epoch 20/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.1889 - accuracy: 0.9291 - val_loss: 0.1313 - val_accuracy: 0.9517
#
# Epoch 00020: val_loss did not improve from 0.00026
# Epoch 21/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.4143 - accuracy: 0.8435 - val_loss: 0.1362 - val_accuracy: 0.9655
#
# Epoch 00021: val_loss did not improve from 0.00026
# Epoch 22/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.2242 - accuracy: 0.9452 - val_loss: 0.1537 - val_accuracy: 0.9448
#
# Epoch 00022: val_loss did not improve from 0.00026
# Epoch 23/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.2144 - accuracy: 0.9194 - val_loss: 0.1932 - val_accuracy: 0.9310
#
# Epoch 00023: val_loss did not improve from 0.00026
# Epoch 24/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.1547 - accuracy: 0.9436 - val_loss: 0.0443 - val_accuracy: 0.9931
#
# Epoch 00024: val_loss did not improve from 0.00026
# Epoch 25/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.1647 - accuracy: 0.9401 - val_loss: 0.0487 - val_accuracy: 0.9862
#
# Epoch 00025: val_loss did not improve from 0.00026
# Epoch 26/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.1103 - accuracy: 0.9592 - val_loss: 0.0682 - val_accuracy: 0.9724
#
# Epoch 00026: val_loss did not improve from 0.00026
# Epoch 27/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0830 - accuracy: 0.9760 - val_loss: 0.0352 - val_accuracy: 0.9931
#
# Epoch 00027: val_loss did not improve from 0.00026
# Epoch 28/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.1258 - accuracy: 0.9560 - val_loss: 0.0325 - val_accuracy: 0.9931
#
# Epoch 00028: val_loss did not improve from 0.00026
# Epoch 29/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0981 - accuracy: 0.9687 - val_loss: 0.0455 - val_accuracy: 0.9862
#
# Epoch 00029: val_loss did not improve from 0.00026
# Epoch 30/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.1506 - accuracy: 0.9442 - val_loss: 0.1546 - val_accuracy: 0.9517
#
# Epoch 00030: val_loss did not improve from 0.00026
# Epoch 31/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.1533 - accuracy: 0.9385 - val_loss: 0.0509 - val_accuracy: 0.9862
#
# Epoch 00031: val_loss did not improve from 0.00026
# Epoch 32/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0687 - accuracy: 0.9774 - val_loss: 0.0464 - val_accuracy: 0.9793
#
# Epoch 00032: val_loss did not improve from 0.00026
# Epoch 33/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0914 - accuracy: 0.9636 - val_loss: 0.0343 - val_accuracy: 0.9862
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00033: val_loss did not improve from 0.00026
# Epoch 34/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0778 - accuracy: 0.9732 - val_loss: 0.0150 - val_accuracy: 0.9931
#
# Epoch 00034: val_loss did not improve from 0.00026
# Epoch 35/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0515 - accuracy: 0.9860 - val_loss: 0.0160 - val_accuracy: 1.0000
#
# Epoch 00035: val_loss did not improve from 0.00026
# Epoch 36/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0416 - accuracy: 0.9867 - val_loss: 0.0151 - val_accuracy: 1.0000
#
# Epoch 00036: val_loss did not improve from 0.00026
# Epoch 37/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0454 - accuracy: 0.9874 - val_loss: 0.0145 - val_accuracy: 1.0000
#
# Epoch 00037: val_loss did not improve from 0.00026
# Epoch 38/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0333 - accuracy: 0.9910 - val_loss: 0.0168 - val_accuracy: 0.9931
#
# Epoch 00038: val_loss did not improve from 0.00026
# Epoch 39/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0477 - accuracy: 0.9866 - val_loss: 0.0177 - val_accuracy: 0.9931
#
# Epoch 00039: val_loss did not improve from 0.00026
# Epoch 40/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0319 - accuracy: 0.9897 - val_loss: 0.0143 - val_accuracy: 1.0000
#
# Epoch 00040: val_loss did not improve from 0.00026
# Epoch 41/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0391 - accuracy: 0.9855 - val_loss: 0.0149 - val_accuracy: 1.0000
#
# Epoch 00041: val_loss did not improve from 0.00026
# Epoch 42/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0449 - accuracy: 0.9859 - val_loss: 0.0141 - val_accuracy: 0.9931
#
# Epoch 00042: val_loss did not improve from 0.00026
# Epoch 43/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0302 - accuracy: 0.9897 - val_loss: 0.0148 - val_accuracy: 0.9931
#
# Epoch 00043: val_loss did not improve from 0.00026
# Epoch 44/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0348 - accuracy: 0.9870 - val_loss: 0.0138 - val_accuracy: 1.0000
#
# Epoch 00044: val_loss did not improve from 0.00026
# Epoch 45/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0280 - accuracy: 0.9969 - val_loss: 0.0145 - val_accuracy: 1.0000
#
# Epoch 00045: val_loss did not improve from 0.00026
# Epoch 46/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0297 - accuracy: 0.9905 - val_loss: 0.0161 - val_accuracy: 0.9931
#
# Epoch 00046: val_loss did not improve from 0.00026
# Epoch 47/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0396 - accuracy: 0.9871 - val_loss: 0.0162 - val_accuracy: 0.9931
#
# Epoch 00047: val_loss did not improve from 0.00026
# Epoch 48/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.0307 - accuracy: 0.9904 - val_loss: 0.0160 - val_accuracy: 0.9931
#
# Epoch 00048: val_loss did not improve from 0.00026
# Epoch 49/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0367 - accuracy: 0.9910 - val_loss: 0.0162 - val_accuracy: 0.9862
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00049: val_loss did not improve from 0.00026
# Epoch 50/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0345 - accuracy: 0.9860 - val_loss: 0.0157 - val_accuracy: 0.9931
#
# Epoch 00050: val_loss did not improve from 0.00026
# Epoch 51/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0268 - accuracy: 0.9924 - val_loss: 0.0150 - val_accuracy: 1.0000
#
# Epoch 00051: val_loss did not improve from 0.00026
# Epoch 52/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0335 - accuracy: 0.9902 - val_loss: 0.0147 - val_accuracy: 0.9931
#
# Epoch 00052: val_loss did not improve from 0.00026
# Epoch 53/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.0295 - accuracy: 0.9909 - val_loss: 0.0148 - val_accuracy: 0.9931
#
# Epoch 00053: val_loss did not improve from 0.00026
# Epoch 54/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0355 - accuracy: 0.9873 - val_loss: 0.0150 - val_accuracy: 1.0000
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00054: val_loss did not improve from 0.00026
# Epoch 55/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0395 - accuracy: 0.9873 - val_loss: 0.0151 - val_accuracy: 1.0000
#
# Epoch 00055: val_loss did not improve from 0.00026
# Epoch 56/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.0346 - accuracy: 0.9878 - val_loss: 0.0150 - val_accuracy: 1.0000
#
# Epoch 00056: val_loss did not improve from 0.00026
# Epoch 57/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0386 - accuracy: 0.9865 - val_loss: 0.0150 - val_accuracy: 1.0000
#
# Epoch 00057: val_loss did not improve from 0.00026
# Epoch 58/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0315 - accuracy: 0.9936 - val_loss: 0.0150 - val_accuracy: 1.0000
#
# Epoch 00058: val_loss did not improve from 0.00026
# Epoch 59/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.0386 - accuracy: 0.9884 - val_loss: 0.0150 - val_accuracy: 1.0000
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00059: val_loss did not improve from 0.00026
# Epoch 00059: early stopping
# 5/5 [==============================] - 5s 906ms/step - loss: 0.0150 - accuracy: 1.0000
# Val Score:  [0.014982137829065323, 1.0]
# ====================================================================================
#
#
# Training on Fold:  3
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 512)               14714688
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_22 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 14,846,787
# Trainable params: 14,846,787
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 47s 5s/step - loss: 2.6857 - accuracy: 0.3388 - val_loss: 1.1029 - val_accuracy: 0.3379
#
# Epoch 00001: val_loss did not improve from 0.00026
# Epoch 2/100
# 10/10 [==============================] - 49s 5s/step - loss: 1.1073 - accuracy: 0.3259 - val_loss: 1.0949 - val_accuracy: 0.3517
#
# Epoch 00002: val_loss did not improve from 0.00026
# Epoch 3/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0979 - accuracy: 0.3680 - val_loss: 1.1066 - val_accuracy: 0.3379
#
# Epoch 00003: val_loss did not improve from 0.00026
# Epoch 4/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.1071 - accuracy: 0.3300 - val_loss: 1.0953 - val_accuracy: 0.3379
#
# Epoch 00004: val_loss did not improve from 0.00026
# Epoch 5/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0989 - accuracy: 0.3341 - val_loss: 1.1059 - val_accuracy: 0.3103
#
# Epoch 00005: val_loss did not improve from 0.00026
# Epoch 6/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0987 - accuracy: 0.3478 - val_loss: 1.1068 - val_accuracy: 0.3379
#
# Epoch 00006: val_loss did not improve from 0.00026
# Epoch 7/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.1090 - accuracy: 0.3099 - val_loss: 1.0968 - val_accuracy: 0.3517
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00007: val_loss did not improve from 0.00026
# Epoch 8/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0982 - accuracy: 0.3451 - val_loss: 1.0876 - val_accuracy: 0.3517
#
# Epoch 00008: val_loss did not improve from 0.00026
# Epoch 9/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0853 - accuracy: 0.4015 - val_loss: 1.0873 - val_accuracy: 0.3379
#
# Epoch 00009: val_loss did not improve from 0.00026
# Epoch 10/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0898 - accuracy: 0.3485 - val_loss: 1.0821 - val_accuracy: 0.3517
#
# Epoch 00010: val_loss did not improve from 0.00026
# Epoch 11/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0785 - accuracy: 0.3747 - val_loss: 1.0634 - val_accuracy: 0.3793
#
# Epoch 00011: val_loss did not improve from 0.00026
# Epoch 12/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0631 - accuracy: 0.4147 - val_loss: 1.0487 - val_accuracy: 0.6483
#
# Epoch 00012: val_loss did not improve from 0.00026
# Epoch 13/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0571 - accuracy: 0.4764 - val_loss: 1.0424 - val_accuracy: 0.4828
#
# Epoch 00013: val_loss did not improve from 0.00026
# Epoch 14/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0399 - accuracy: 0.4854 - val_loss: 1.0037 - val_accuracy: 0.6000
#
# Epoch 00014: val_loss did not improve from 0.00026
# Epoch 15/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9997 - accuracy: 0.5595 - val_loss: 1.0371 - val_accuracy: 0.3724
#
# Epoch 00015: val_loss did not improve from 0.00026
# Epoch 16/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0209 - accuracy: 0.4414 - val_loss: 1.0201 - val_accuracy: 0.4069
#
# Epoch 00016: val_loss did not improve from 0.00026
# Epoch 17/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9935 - accuracy: 0.4782 - val_loss: 0.9045 - val_accuracy: 0.6414
#
# Epoch 00017: val_loss did not improve from 0.00026
# Epoch 18/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.9719 - accuracy: 0.4830 - val_loss: 1.0008 - val_accuracy: 0.4552
#
# Epoch 00018: val_loss did not improve from 0.00026
# Epoch 19/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9299 - accuracy: 0.5340 - val_loss: 0.8485 - val_accuracy: 0.5931
#
# Epoch 00019: val_loss did not improve from 0.00026
# Epoch 20/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.8478 - accuracy: 0.6228 - val_loss: 1.0331 - val_accuracy: 0.4483
#
# Epoch 00020: val_loss did not improve from 0.00026
# Epoch 21/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9026 - accuracy: 0.5287 - val_loss: 0.7263 - val_accuracy: 0.7241
#
# Epoch 00021: val_loss did not improve from 0.00026
# Epoch 22/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.7807 - accuracy: 0.6634 - val_loss: 0.7211 - val_accuracy: 0.7034
#
# Epoch 00022: val_loss did not improve from 0.00026
# Epoch 23/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.7348 - accuracy: 0.7064 - val_loss: 0.6444 - val_accuracy: 0.7931
#
# Epoch 00023: val_loss did not improve from 0.00026
# Epoch 24/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.7250 - accuracy: 0.7349 - val_loss: 0.5738 - val_accuracy: 0.8069
#
# Epoch 00024: val_loss did not improve from 0.00026
# Epoch 25/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.7194 - accuracy: 0.7163 - val_loss: 0.6426 - val_accuracy: 0.6414
#
# Epoch 00025: val_loss did not improve from 0.00026
# Epoch 26/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.6436 - accuracy: 0.7468 - val_loss: 0.5335 - val_accuracy: 0.7517
#
# Epoch 00026: val_loss did not improve from 0.00026
# Epoch 27/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.5791 - accuracy: 0.7580 - val_loss: 0.4189 - val_accuracy: 0.9103
#
# Epoch 00027: val_loss did not improve from 0.00026
# Epoch 28/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.5824 - accuracy: 0.7516 - val_loss: 0.6611 - val_accuracy: 0.6138
#
# Epoch 00028: val_loss did not improve from 0.00026
# Epoch 29/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.5160 - accuracy: 0.7920 - val_loss: 0.9044 - val_accuracy: 0.5034
#
# Epoch 00029: val_loss did not improve from 0.00026
# Epoch 30/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.4418 - accuracy: 0.8478 - val_loss: 1.0165 - val_accuracy: 0.4690
#
# Epoch 00030: val_loss did not improve from 0.00026
# Epoch 31/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.4208 - accuracy: 0.8390 - val_loss: 0.7156 - val_accuracy: 0.6276
#
# Epoch 00031: val_loss did not improve from 0.00026
# Epoch 32/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.3665 - accuracy: 0.8672 - val_loss: 0.5224 - val_accuracy: 0.7724
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00032: val_loss did not improve from 0.00026
# Epoch 33/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.3154 - accuracy: 0.8896 - val_loss: 0.5994 - val_accuracy: 0.7241
#
# Epoch 00033: val_loss did not improve from 0.00026
# Epoch 34/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.2817 - accuracy: 0.9041 - val_loss: 0.5633 - val_accuracy: 0.7310
#
# Epoch 00034: val_loss did not improve from 0.00026
# Epoch 35/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.2762 - accuracy: 0.9066 - val_loss: 0.7493 - val_accuracy: 0.6897
#
# Epoch 00035: val_loss did not improve from 0.00026
# Epoch 36/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.3005 - accuracy: 0.8888 - val_loss: 0.6254 - val_accuracy: 0.7379
#
# Epoch 00036: val_loss did not improve from 0.00026
# Epoch 37/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.2330 - accuracy: 0.9257 - val_loss: 0.5479 - val_accuracy: 0.7448
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00037: val_loss did not improve from 0.00026
# Epoch 38/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.2690 - accuracy: 0.8962 - val_loss: 0.5858 - val_accuracy: 0.7448
#
# Epoch 00038: val_loss did not improve from 0.00026
# Epoch 39/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.2631 - accuracy: 0.9093 - val_loss: 0.6126 - val_accuracy: 0.7517
#
# Epoch 00039: val_loss did not improve from 0.00026
# Epoch 40/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.2435 - accuracy: 0.9227 - val_loss: 0.6171 - val_accuracy: 0.7448
#
# Epoch 00040: val_loss did not improve from 0.00026
# Epoch 41/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.2570 - accuracy: 0.9220 - val_loss: 0.6053 - val_accuracy: 0.7517
#
# Epoch 00041: val_loss did not improve from 0.00026
# Epoch 42/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.2713 - accuracy: 0.9133 - val_loss: 0.6027 - val_accuracy: 0.7517
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00042: val_loss did not improve from 0.00026
# Epoch 00042: early stopping
# 5/5 [==============================] - 5s 905ms/step - loss: 0.6027 - accuracy: 0.7517
# Val Score:  [0.6027423739433289, 0.751724123954773]
# ====================================================================================
#
#
# Training on Fold:  4
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 512)               14714688
# _________________________________________________________________
# dense_23 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_24 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 14,846,787
# Trainable params: 14,846,787
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 47s 5s/step - loss: 1.6137 - accuracy: 0.3615 - val_loss: 1.0851 - val_accuracy: 0.3517
#
# Epoch 00001: val_loss did not improve from 0.00026
# Epoch 2/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.1371 - accuracy: 0.3524 - val_loss: 1.1181 - val_accuracy: 0.2759
#
# Epoch 00002: val_loss did not improve from 0.00026
# Epoch 3/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0994 - accuracy: 0.3377 - val_loss: 1.1366 - val_accuracy: 0.2759
#
# Epoch 00003: val_loss did not improve from 0.00026
# Epoch 4/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0987 - accuracy: 0.3755 - val_loss: 1.1843 - val_accuracy: 0.3517
#
# Epoch 00004: val_loss did not improve from 0.00026
# Epoch 5/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.1455 - accuracy: 0.3919 - val_loss: 1.0889 - val_accuracy: 0.3379
#
# Epoch 00005: val_loss did not improve from 0.00026
# Epoch 6/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0687 - accuracy: 0.4429 - val_loss: 1.0136 - val_accuracy: 0.3724
#
# Epoch 00006: val_loss did not improve from 0.00026
# Epoch 7/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0152 - accuracy: 0.5402 - val_loss: 2.9595 - val_accuracy: 0.3517
#
# Epoch 00007: val_loss did not improve from 0.00026
# Epoch 8/100
# 10/10 [==============================] - 49s 5s/step - loss: 1.7301 - accuracy: 0.3231 - val_loss: 1.1144 - val_accuracy: 0.2759
#
# Epoch 00008: val_loss did not improve from 0.00026
# Epoch 9/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.1098 - accuracy: 0.3335 - val_loss: 1.1310 - val_accuracy: 0.2759
#
# Epoch 00009: val_loss did not improve from 0.00026
# Epoch 10/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.1424 - accuracy: 0.3339 - val_loss: 1.1052 - val_accuracy: 0.3517
#
# Epoch 00010: val_loss did not improve from 0.00026
# Epoch 11/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.1176 - accuracy: 0.2915 - val_loss: 1.0877 - val_accuracy: 0.3724
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00011: val_loss did not improve from 0.00026
# Epoch 12/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0993 - accuracy: 0.3347 - val_loss: 1.0910 - val_accuracy: 0.4276
#
# Epoch 00012: val_loss did not improve from 0.00026
# Epoch 13/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0909 - accuracy: 0.3530 - val_loss: 1.0926 - val_accuracy: 0.3517
#
# Epoch 00013: val_loss did not improve from 0.00026
# Epoch 14/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0863 - accuracy: 0.3613 - val_loss: 1.0836 - val_accuracy: 0.5517
#
# Epoch 00014: val_loss did not improve from 0.00026
# Epoch 15/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0805 - accuracy: 0.5022 - val_loss: 1.0664 - val_accuracy: 0.3724
#
# Epoch 00015: val_loss did not improve from 0.00026
# Epoch 16/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0742 - accuracy: 0.3802 - val_loss: 1.0597 - val_accuracy: 0.5448
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00016: val_loss did not improve from 0.00026
# Epoch 17/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0557 - accuracy: 0.5763 - val_loss: 1.0544 - val_accuracy: 0.5586
#
# Epoch 00017: val_loss did not improve from 0.00026
# Epoch 18/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0493 - accuracy: 0.5698 - val_loss: 1.0481 - val_accuracy: 0.5586
#
# Epoch 00018: val_loss did not improve from 0.00026
# Epoch 19/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0412 - accuracy: 0.5873 - val_loss: 1.0385 - val_accuracy: 0.5586
#
# Epoch 00019: val_loss did not improve from 0.00026
# Epoch 20/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0358 - accuracy: 0.5910 - val_loss: 1.0250 - val_accuracy: 0.5379
#
# Epoch 00020: val_loss did not improve from 0.00026
# Epoch 21/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0204 - accuracy: 0.6426 - val_loss: 1.0136 - val_accuracy: 0.5724
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00021: val_loss did not improve from 0.00026
# Epoch 22/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0137 - accuracy: 0.6447 - val_loss: 1.0121 - val_accuracy: 0.5655
#
# Epoch 00022: val_loss did not improve from 0.00026
# Epoch 23/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0113 - accuracy: 0.6527 - val_loss: 1.0108 - val_accuracy: 0.5724
#
# Epoch 00023: val_loss did not improve from 0.00026
# Epoch 24/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0122 - accuracy: 0.6798 - val_loss: 1.0094 - val_accuracy: 0.5655
#
# Epoch 00024: val_loss did not improve from 0.00026
# Epoch 25/100
# 10/10 [==============================] - 49s 5s/step - loss: 1.0094 - accuracy: 0.6687 - val_loss: 1.0083 - val_accuracy: 0.5724
#
# Epoch 00025: val_loss did not improve from 0.00026
# Epoch 26/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0107 - accuracy: 0.6935 - val_loss: 1.0072 - val_accuracy: 0.5793
#
# Epoch 00026: val_loss did not improve from 0.00026
# Epoch 27/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0080 - accuracy: 0.6849 - val_loss: 1.0059 - val_accuracy: 0.5793
#
# Epoch 00027: val_loss did not improve from 0.00026
# Epoch 28/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0062 - accuracy: 0.7077 - val_loss: 1.0045 - val_accuracy: 0.5724
#
# Epoch 00028: val_loss did not improve from 0.00026
# Epoch 29/100
# 10/10 [==============================] - 49s 5s/step - loss: 1.0027 - accuracy: 0.7090 - val_loss: 1.0032 - val_accuracy: 0.5586
#
# Epoch 00029: val_loss did not improve from 0.00026
# Epoch 30/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0060 - accuracy: 0.6808 - val_loss: 1.0021 - val_accuracy: 0.5586
#
# Epoch 00030: val_loss did not improve from 0.00026
# Epoch 31/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0033 - accuracy: 0.7130 - val_loss: 1.0012 - val_accuracy: 0.6069
#
# Epoch 00031: val_loss did not improve from 0.00026
# Epoch 32/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0088 - accuracy: 0.7162 - val_loss: 1.0004 - val_accuracy: 0.6276
#
# Epoch 00032: val_loss did not improve from 0.00026
# Epoch 33/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0042 - accuracy: 0.7133 - val_loss: 0.9993 - val_accuracy: 0.6276
#
# Epoch 00033: val_loss did not improve from 0.00026
# Epoch 34/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0046 - accuracy: 0.7246 - val_loss: 0.9981 - val_accuracy: 0.6138
#
# Epoch 00034: val_loss did not improve from 0.00026
# Epoch 35/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9987 - accuracy: 0.7243 - val_loss: 0.9968 - val_accuracy: 0.6069
#
# Epoch 00035: val_loss did not improve from 0.00026
# Epoch 36/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0009 - accuracy: 0.7248 - val_loss: 0.9954 - val_accuracy: 0.5862
#
# Epoch 00036: val_loss did not improve from 0.00026
# Epoch 37/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0003 - accuracy: 0.6889 - val_loss: 0.9942 - val_accuracy: 0.5931
#
# Epoch 00037: val_loss did not improve from 0.00026
# Epoch 38/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9913 - accuracy: 0.7311 - val_loss: 0.9930 - val_accuracy: 0.6069
#
# Epoch 00038: val_loss did not improve from 0.00026
# Epoch 39/100
# ...
#
# Epoch 00043: val_loss did not improve from 0.00026
# Epoch 44/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9799 - accuracy: 0.7624 - val_loss: 0.9856 - val_accuracy: 0.6138
#
# Epoch 00044: val_loss did not improve from 0.00026
# Epoch 45/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.9833 - accuracy: 0.7320 - val_loss: 0.9843 - val_accuracy: 0.6138
#
# Epoch 00045: val_loss did not improve from 0.00026
# Epoch 46/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9852 - accuracy: 0.7305 - val_loss: 0.9829 - val_accuracy: 0.6276
#
# Epoch 00046: val_loss did not improve from 0.00026
# Epoch 47/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9817 - accuracy: 0.7481 - val_loss: 0.9814 - val_accuracy: 0.6276
#
# Epoch 00047: val_loss did not improve from 0.00026
# Epoch 48/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9857 - accuracy: 0.7518 - val_loss: 0.9800 - val_accuracy: 0.6345
#
# Epoch 00048: val_loss did not improve from 0.00026
# Epoch 49/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9814 - accuracy: 0.7389 - val_loss: 0.9784 - val_accuracy: 0.6483
#
# Epoch 00049: val_loss did not improve from 0.00026
# Epoch 50/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9847 - accuracy: 0.7348 - val_loss: 0.9768 - val_accuracy: 0.6414
#
# Epoch 00050: val_loss did not improve from 0.00026
# Epoch 51/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.9803 - accuracy: 0.7328 - val_loss: 0.9754 - val_accuracy: 0.6483
#
# Epoch 00051: val_loss did not improve from 0.00026
# Epoch 52/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9784 - accuracy: 0.7382 - val_loss: 0.9738 - val_accuracy: 0.6483
#
# Epoch 00052: val_loss did not improve from 0.00026
# Epoch 53/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.9778 - accuracy: 0.7714 - val_loss: 0.9723 - val_accuracy: 0.6483
#
# Epoch 00053: val_loss did not improve from 0.00026
# Epoch 54/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9784 - accuracy: 0.7480 - val_loss: 0.9708 - val_accuracy: 0.6483
#
# Epoch 00054: val_loss did not improve from 0.00026
# Epoch 55/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9722 - accuracy: 0.7440 - val_loss: 0.9691 - val_accuracy: 0.6345
#
# Epoch 00055: val_loss did not improve from 0.00026
# Epoch 56/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9730 - accuracy: 0.7386 - val_loss: 0.9675 - val_accuracy: 0.6483
#
# Epoch 00056: val_loss did not improve from 0.00026
# Epoch 57/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9739 - accuracy: 0.7186 - val_loss: 0.9659 - val_accuracy: 0.6621
#
# Epoch 00057: val_loss did not improve from 0.00026
# Epoch 58/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9745 - accuracy: 0.7569 - val_loss: 0.9643 - val_accuracy: 0.6621
#
# Epoch 00058: val_loss did not improve from 0.00026
# Epoch 59/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9661 - accuracy: 0.7529 - val_loss: 0.9628 - val_accuracy: 0.6621
#
# Epoch 00059: val_loss did not improve from 0.00026
# Epoch 60/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.9704 - accuracy: 0.7503 - val_loss: 0.9612 - val_accuracy: 0.6690
#
# Epoch 00060: val_loss did not improve from 0.00026
# Epoch 61/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9659 - accuracy: 0.7639 - val_loss: 0.9595 - val_accuracy: 0.6621
#
# Epoch 00061: val_loss did not improve from 0.00026
# Epoch 62/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9641 - accuracy: 0.7541 - val_loss: 0.9578 - val_accuracy: 0.6483
#
# Epoch 00062: val_loss did not improve from 0.00026
# Epoch 63/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9645 - accuracy: 0.7399 - val_loss: 0.9561 - val_accuracy: 0.6552
#
# Epoch 00063: val_loss did not improve from 0.00026
# Epoch 64/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9572 - accuracy: 0.7697 - val_loss: 0.9544 - val_accuracy: 0.6621
#
# Epoch 00064: val_loss did not improve from 0.00026
# Epoch 65/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9609 - accuracy: 0.7747 - val_loss: 0.9528 - val_accuracy: 0.6345
#
# Epoch 00065: val_loss did not improve from 0.00026
# Epoch 66/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9547 - accuracy: 0.7465 - val_loss: 0.9510 - val_accuracy: 0.6276
#
# Epoch 00066: val_loss did not improve from 0.00026
# Epoch 67/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9488 - accuracy: 0.7665 - val_loss: 0.9491 - val_accuracy: 0.6207
#
# Epoch 00067: val_loss did not improve from 0.00026
# Epoch 68/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9466 - accuracy: 0.7656 - val_loss: 0.9473 - val_accuracy: 0.6207
#
# Epoch 00068: val_loss did not improve from 0.00026
# Epoch 69/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9483 - accuracy: 0.7480 - val_loss: 0.9454 - val_accuracy: 0.6276
#
# Epoch 00069: val_loss did not improve from 0.00026
# Epoch 70/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9555 - accuracy: 0.7389 - val_loss: 0.9437 - val_accuracy: 0.6414
#
# Epoch 00070: val_loss did not improve from 0.00026
# Epoch 71/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9475 - accuracy: 0.7544 - val_loss: 0.9419 - val_accuracy: 0.6414
#
# Epoch 00071: val_loss did not improve from 0.00026
# Epoch 72/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9490 - accuracy: 0.7625 - val_loss: 0.9400 - val_accuracy: 0.6483
#
# Epoch 00072: val_loss did not improve from 0.00026
# Epoch 73/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9430 - accuracy: 0.7523 - val_loss: 0.9381 - val_accuracy: 0.6414
#
# Epoch 00073: val_loss did not improve from 0.00026
# Epoch 74/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9441 - accuracy: 0.7648 - val_loss: 0.9364 - val_accuracy: 0.6690
#
# Epoch 00074: val_loss did not improve from 0.00026
# Epoch 75/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9300 - accuracy: 0.7749 - val_loss: 0.9345 - val_accuracy: 0.6621
#
# Epoch 00075: val_loss did not improve from 0.00026
# Epoch 76/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9414 - accuracy: 0.7564 - val_loss: 0.9326 - val_accuracy: 0.6621
#
# Epoch 00076: val_loss did not improve from 0.00026
# Epoch 77/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9381 - accuracy: 0.7578 - val_loss: 0.9307 - val_accuracy: 0.6621
#
# Epoch 00077: val_loss did not improve from 0.00026
# Epoch 78/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9317 - accuracy: 0.7537 - val_loss: 0.9289 - val_accuracy: 0.6621
#
# Epoch 00078: val_loss did not improve from 0.00026
# Epoch 79/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.9341 - accuracy: 0.7654 - val_loss: 0.9270 - val_accuracy: 0.6621
#
# Epoch 00079: val_loss did not improve from 0.00026
# Epoch 80/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9355 - accuracy: 0.7611 - val_loss: 0.9251 - val_accuracy: 0.6828
#
# Epoch 00080: val_loss did not improve from 0.00026
# Epoch 81/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9260 - accuracy: 0.7515 - val_loss: 0.9231 - val_accuracy: 0.6621
#
# Epoch 00081: val_loss did not improve from 0.00026
# Epoch 82/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9344 - accuracy: 0.7434 - val_loss: 0.9212 - val_accuracy: 0.6621
#
# Epoch 00082: val_loss did not improve from 0.00026
# Epoch 83/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9200 - accuracy: 0.7659 - val_loss: 0.9193 - val_accuracy: 0.6621
#
# Epoch 00083: val_loss did not improve from 0.00026
# Epoch 84/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9279 - accuracy: 0.7371 - val_loss: 0.9172 - val_accuracy: 0.6828
#
# Epoch 00084: val_loss did not improve from 0.00026
# Epoch 85/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9306 - accuracy: 0.7456 - val_loss: 0.9153 - val_accuracy: 0.6897
#
# Epoch 00085: val_loss did not improve from 0.00026
# Epoch 86/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9229 - accuracy: 0.7523 - val_loss: 0.9133 - val_accuracy: 0.6690
#
# Epoch 00086: val_loss did not improve from 0.00026
# Epoch 87/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9239 - accuracy: 0.7425 - val_loss: 0.9113 - val_accuracy: 0.6759
#
# Epoch 00087: val_loss did not improve from 0.00026
# Epoch 88/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9119 - accuracy: 0.7389 - val_loss: 0.9091 - val_accuracy: 0.6759
#
# Epoch 00088: val_loss did not improve from 0.00026
# Epoch 89/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9117 - accuracy: 0.7910 - val_loss: 0.9071 - val_accuracy: 0.6966
#
# Epoch 00089: val_loss did not improve from 0.00026
# Epoch 90/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9158 - accuracy: 0.7444 - val_loss: 0.9050 - val_accuracy: 0.6966
#
# Epoch 00090: val_loss did not improve from 0.00026
# Epoch 91/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9173 - accuracy: 0.7494 - val_loss: 0.9029 - val_accuracy: 0.6966
#
# Epoch 00091: val_loss did not improve from 0.00026
# Epoch 92/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9054 - accuracy: 0.7720 - val_loss: 0.9006 - val_accuracy: 0.6897
#
# Epoch 00092: val_loss did not improve from 0.00026
# Epoch 93/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.9157 - accuracy: 0.7548 - val_loss: 0.8985 - val_accuracy: 0.6966
#
# Epoch 00093: val_loss did not improve from 0.00026
# Epoch 94/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9020 - accuracy: 0.7530 - val_loss: 0.8963 - val_accuracy: 0.6897
#
# Epoch 00094: val_loss did not improve from 0.00026
# Epoch 95/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.9134 - accuracy: 0.7603 - val_loss: 0.8940 - val_accuracy: 0.6897
#
# Epoch 00095: val_loss did not improve from 0.00026
# Epoch 96/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.8976 - accuracy: 0.7703 - val_loss: 0.8917 - val_accuracy: 0.6828
#
# Epoch 00096: val_loss did not improve from 0.00026
# Epoch 97/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.8929 - accuracy: 0.7671 - val_loss: 0.8893 - val_accuracy: 0.6828
#
# Epoch 00097: val_loss did not improve from 0.00026
# Epoch 98/100
# 10/10 [==============================] - 49s 5s/step - loss: 0.8967 - accuracy: 0.7406 - val_loss: 0.8868 - val_accuracy: 0.6966
#
# Epoch 00098: val_loss did not improve from 0.00026
# Epoch 99/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.8938 - accuracy: 0.7582 - val_loss: 0.8844 - val_accuracy: 0.7172
#
# Epoch 00099: val_loss did not improve from 0.00026
# Epoch 100/100
# 10/10 [==============================] - 45s 4s/step - loss: 0.8946 - accuracy: 0.7526 - val_loss: 0.8820 - val_accuracy: 0.7379
#
# Epoch 00100: val_loss did not improve from 0.00026
# 5/5 [==============================] - 5s 910ms/step - loss: 0.8820 - accuracy: 0.7379
# Val Score:  [0.8820310235023499, 0.7379310131072998]
# ====================================================================================
#
#
# Training on Fold:  5
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 512)               14714688
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_26 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 14,846,787
# Trainable params: 14,846,787
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 47s 5s/step - loss: 2.7957 - accuracy: 0.3995 - val_loss: 1.1894 - val_accuracy: 0.3310
#
# Epoch 00001: val_loss did not improve from 0.00026
# Epoch 2/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.1532 - accuracy: 0.3210 - val_loss: 1.0989 - val_accuracy: 0.3517
#
# Epoch 00002: val_loss did not improve from 0.00026
# Epoch 3/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.1114 - accuracy: 0.3126 - val_loss: 1.1002 - val_accuracy: 0.3310
#
# Epoch 00003: val_loss did not improve from 0.00026
# Epoch 4/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0979 - accuracy: 0.3367 - val_loss: 1.1029 - val_accuracy: 0.3034
#
# Epoch 00004: val_loss did not improve from 0.00026
# Epoch 5/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.1004 - accuracy: 0.3323 - val_loss: 1.1008 - val_accuracy: 0.3034
#
# Epoch 00005: val_loss did not improve from 0.00026
# Epoch 6/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0996 - accuracy: 0.3444 - val_loss: 1.0999 - val_accuracy: 0.3034
#
# Epoch 00006: val_loss did not improve from 0.00026
# Epoch 7/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0981 - accuracy: 0.3467 - val_loss: 1.1006 - val_accuracy: 0.3034
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00007: val_loss did not improve from 0.00026
# Epoch 8/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0973 - accuracy: 0.3431 - val_loss: 1.1007 - val_accuracy: 0.3034
#
# Epoch 00008: val_loss did not improve from 0.00026
# Epoch 9/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0973 - accuracy: 0.3588 - val_loss: 1.1008 - val_accuracy: 0.3034
#
# Epoch 00009: val_loss did not improve from 0.00026
# Epoch 10/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0979 - accuracy: 0.3427 - val_loss: 1.1009 - val_accuracy: 0.3034
#
# Epoch 00010: val_loss did not improve from 0.00026
# Epoch 11/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0971 - accuracy: 0.3502 - val_loss: 1.1010 - val_accuracy: 0.3034
#
# Epoch 00011: val_loss did not improve from 0.00026
# Epoch 12/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0975 - accuracy: 0.3387 - val_loss: 1.1009 - val_accuracy: 0.3034
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00012: val_loss did not improve from 0.00026
# Epoch 13/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0971 - accuracy: 0.3549 - val_loss: 1.1009 - val_accuracy: 0.3034
#
# Epoch 00013: val_loss did not improve from 0.00026
# Epoch 14/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.0971 - accuracy: 0.3632 - val_loss: 1.1009 - val_accuracy: 0.3034
#
# Epoch 00014: val_loss did not improve from 0.00026
# Epoch 15/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0982 - accuracy: 0.3301 - val_loss: 1.1009 - val_accuracy: 0.3034
#
# Epoch 00015: val_loss did not improve from 0.00026
# Epoch 16/100
# 10/10 [==============================] - 45s 5s/step - loss: 1.0980 - accuracy: 0.3171 - val_loss: 1.1009 - val_accuracy: 0.3034
#
# Epoch 00016: val_loss did not improve from 0.00026
# Epoch 17/100
# 10/10 [==============================] - 45s 4s/step - loss: 1.0971 - accuracy: 0.3543 - val_loss: 1.1010 - val_accuracy: 0.3034
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00017: val_loss did not improve from 0.00026
# Epoch 00017: early stopping
# 5/5 [==============================] - 5s 906ms/step - loss: 1.1010 - accuracy: 0.3034
# Val Score:  [1.1009529829025269, 0.30344828963279724]
# ====================================================================================

# %%
sns.set(font_scale=2)
sns.set_style('whitegrid')
plt.figure(figsize=(15, 6))
plt.title('Train Accuracy vs Val Accuracy (VGG16)')
plt.plot(VGG_model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt.plot(VGG_model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='black', linestyle = "dashdot")
plt.plot(VGG_model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red', )
plt.plot(VGG_model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='red', linestyle = "dashdot")
plt.plot(VGG_model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green', )
plt.plot(VGG_model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='green', linestyle = "dashdot")
plt.plot(VGG_model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue', )
plt.plot(VGG_model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='blue', linestyle = "dashdot")
plt.plot(VGG_model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='c', )
plt.plot(VGG_model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='c', linestyle = "dashdot")
plt.legend(prop={'size': 15},
          fancybox=True, shadow=True)
plt.show()

# %%
sns.set(font_scale=2)
sns.set_style('whitegrid')
plt.figure(figsize=(15, 6))
plt.title('Train Loss vs Val Loss (VGG16)')
plt.plot(VGG_model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt.plot(VGG_model_history[0].history['val_loss'], label='Val Loss Fold 1', color='black', linestyle = "dashdot")
plt.plot(VGG_model_history[1].history['loss'], label='Train Loss Fold 2', color='red', )
plt.plot(VGG_model_history[1].history['val_loss'], label='Val Loss Fold 2', color='red', linestyle = "dashdot")
plt.plot(VGG_model_history[2].history['loss'], label='Train Loss Fold 3', color='green', )
plt.plot(VGG_model_history[2].history['val_loss'], label='Val Loss Fold 3', color='green', linestyle = "dashdot")
plt.plot(VGG_model_history[3].history['loss'], label='Train Loss Fold 4', color='blue', )
plt.plot(VGG_model_history[3].history['val_loss'], label='Val Loss Fold 4', color='blue', linestyle = "dashdot")
plt.plot(VGG_model_history[4].history['loss'], label='Train Loss Fold 5', color='c', )
plt.plot(VGG_model_history[4].history['val_loss'], label='Val Loss Fold 5', color='c', linestyle = "dashdot")
plt.legend(prop={'size': 15},
          fancybox=True, shadow=True)
plt.show()

# %%
#Load the model that was saved by ModelCheckpoint
nFoldVGG16Model = load_model('F:\\Ml files\\jute disease\\model\\K-fold-11_VGG16.h5')
preds=nFoldVGG16Model.predict(x_test)
predictions=np.argmax(preds,axis=1)

# %%
from sklearn.metrics import classification_report
Y_test =np.argmax(y_test,axis=1)
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       124
#            1       0.99      1.00      1.00       105
#            2       0.98      0.99      0.98       132
#
#     accuracy                           0.99       361
#    macro avg       0.99      0.99      0.99       361
# weighted avg       0.99      0.99      0.99       361

# %%
report_generate(Y_test, predictions)
# Out:
# (None,
#                  precision  recall  f1-score
#  Healthy             99.17   96.77     97.96
#  Powdery mildew      99.06  100.00     99.53
#  Yellow mosaic       97.76   99.24     98.50
#  accuracy            98.61   98.61     98.61
#  macro avg           98.66   98.67     98.66
#  weighted avg        98.62   98.61     98.61)

# %%
conf_matrix(Y_test,predictions)

# %%
# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(categories):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)

print('ROC AUC score:', multiclass_roc_auc_score(Y_test,predictions))

c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
plt.show()
# Out:
# ROC AUC score: 0.9898233469906984

# %% [markdown]
# # InceptionV3

# %%
from tensorflow.keras.applications import InceptionV3

# %%
def incV3_model(input_shape):
    IncV3 = InceptionV3(include_top = False, weights = "imagenet",input_shape = (input_shape))
    model = Sequential()
    model.add(IncV3)
    
    for layer in model.layers:
        layer.trainable = False


    model.add(Flatten())

    model.add(Dense(units = 2048, activation = "relu"))
    model.add(Dropout(0.5))
    model.add(Dense(units = 3, activation = "softmax"))
    
    model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
    model.summary()
    return model

# %%
#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=50, BATCH_SIZE=128):
    model = None
    input_shape = 150,150,3
    model = incV3_model(input_shape)
    results = model.fit_generator(datagen.flow(t_x, t_y, batch_size=BATCH_SIZE),
                              epochs = EPOCHS, validation_data = (val_x,val_y),
                              callbacks= callbacks,
                              verbose = 1, steps_per_epoch= t_x.shape[0] // 128)
    
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
checkpoint_path = 'F:\\Ml files\\jute disease\\model\\K-fold-11_INCV3.h5'
callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', patience=15, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint(monitor='val_loss', mode='min', filepath=checkpoint_path, verbose=1, save_best_only=True, save_weights_only=False),
    acc_callback
]

# %%
n_folds=5
epochs = 100
batch_size = 128

INCV3_model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    INCV3_model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 40s 0us/step
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_27 (Dense)             (None, 2048)              37750784
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 3)                 6147
# =================================================================
# Total params: 59,559,715
# Trainable params: 37,756,931
# Non-trainable params: 21,802,784
# _________________________________________________________________
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14400/1427712331.py in <module>
#       9     t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.1,
#      10                                                random_state = np.random.randint(1,1000, 1)[0])
# ---> 11     INCV3_model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
#      12     print("======="*12, end="\n\n\n")
#
# ~\AppData\Local\Temp/ipykernel_14400/2330068021.py in fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS, BATCH_SIZE)
#       4     input_shape = 150,150,3
#       5     model = incV3_model(input_shape)
# ----> 6     results = model.fit_generator(datagen.flow(t_x, t_y, batch_size=BATCH_SIZE),
#       7                               epochs = EPOCHS, validation_data = (val_x,val_y),
#       8                               callbacks= callbacks,
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\tensorflow\python\keras\preprocessing\image.py in flow(self, x, y, batch_size, shuffle, sample_weight, seed, save_to_dir, save_prefix, save_format, subset)
#     863         save_prefix=save_prefix,
#     864         save_format=save_format,
# --> 865         subset=subset)
#     866
#     867   def flow_from_directory(self,
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\tensorflow\python\keras\preprocessing\image.py in __init__(self, x, y, image_data_generator, batch_size, shuffle, sample_weight, seed, data_format, save_to_dir, save_prefix, save_format, subset, dtype)
#     458         save_format=save_format,
#     459         subset=subset,
# --> 460         **kwargs)
#     461
#     462
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\keras_preprocessing\image\numpy_array_iterator.py in __init__(self, x, y, image_data_generator, batch_size, shuffle, sample_weight, seed, data_format, save_to_dir, save_prefix, save_format, subset, dtype)
#     119                     y = y[split_idx:]
#     120
# --> 121         self.x = np.asarray(x, dtype=self.dtype)
#     122         self.x_misc = x_misc
#     123         if self.x.ndim != 4:
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# MemoryError: Unable to allocate 334. MiB for an array with shape (1299, 150, 150, 3) and data type float32
